# %%
file1='tmp/kgtk_conceptnet.tsv'
file2='tmp/kgtk_wordnet.tsv'

# %%
from tqdm import tqdm

# %%
def get_all_labels(l):
    if '|' not in l:
        return [l]
    else:
        return [l2 for l2 in l.split('|') if l2!='']

# %%
def get_triples(a_file):
    triples=set()
    with open(a_file, 'r') as f1:
        header=next(f1)
        for line in tqdm(f1, total=3500000):
            data=line.split('\t')
            rel_label=data[5]
            for n1_label in get_all_labels(data[3]):
                for n2_label in get_all_labels(data[4]):
                    if n1_label=='' or n2_label=='': print(data)
                    triple=(n1_label, rel_label, n2_label)
                    triples.add(triple)
    return triples

# %%
f1_triples=get_triples(file1)
# Out:
#  98%|█████████▊| 3423004/3500000 [00:05<00:00, 582750.67it/s]

# %%
f2_triples=get_triples(file2)
# Out:
#   3%|▎         | 111276/3500000 [00:00<00:12, 264835.47it/s]

# %% [markdown]
# ## Both sources have it

# %%
both_triples=set(f1_triples) & set(f2_triples)

# %%
print(len(both_triples), len(f1_triples), len(f2_triples))
# Out:
# 61406 3323321 420716

# %% [markdown]
# ## Only source 2 has it

# %%
len(set(f2_triples)-set(f1_triples))
# Out:
# 359310

# %%
f2_triples-f1_triples
# Out:
# {('ionisation', 'is a', 'activity'),
#  ('family Cobitidae', 'is a part of', 'order Cypriniformes'),
#  ('cortical area', 'is a', 'region'),
#  ('living rock', 'is a part of', 'genus Ariocarpus'),
#  ('steel grey', 'is a', 'greyness'),
#  ('hard-boiled egg', 'is a', 'boiled egg'),
#  ('Cronartium', 'is a part of', 'Melampsoraceae'),
#  ('bilingual', 'is a', 'polyglot'),
#  ('family Procaviidae', 'is a part of', 'order Hyracoidea'),
#  ('quick fix', 'is a', 'fixture'),
#  ('governing body', 'is a part of', 'government'),
#  ('Pacific Northwest', 'is a part of', 'United States of America'),
#  ('Brunswick', 'is a part of', 'Federal Republic of Germany'),
#  ('Chios', 'is a part of', 'Ellas'),
#  ('laissez faire', 'is a', 'doctrine'),
#  ('go-ahead', 'is a', 'stoplight'),
#  ('chatterbox', 'is a', 'verbalizer'),
#  ('Rau-Sed', 'is a', 'antihypertensive drug'),
#  ("Takayasu's arteritis", 'is a', 'arteritis'),
#  ('marihuana', 'is a part of', 'hemp'),
#  ('Tragopogon porrifolius', 'is a part of', 'Tragopogon'),
#  ('bump', 'is a', 'assign'),
#  ('carbineer', 'is a', 'rifleman'),
#  ('funicular', 'is a', 'railroad line'),
#  ('watermeal', 'is a part of', 'genus Wolffia'),
#  ('genus Anasa', 'is a part of', 'Coreidae'),
#  ('Low German', 'is a', 'West Germanic language'),
#  ('solo', 'is a', 'aviate'),
#  ('swede', 'is a part of', 'Swedish turnip'),
#  ('leading man', 'is a', 'histrion'),
#  ('Salix lucida', 'is a', 'willow tree'),
#  ('periphery', 'is a', 'edge'),
#  ('foster-child', 'is a', 'youngster'),
#  ('karyokinesis', 'is a part of', 'miosis'),
#  ('muscadine', 'is a part of', 'muscadine'),
#  ('one-tenth', 'is a', 'simple fraction'),
#  ('tattletale grey', 'is a', 'gray'),
#  ('blow', 'is a', 'discharge'),
#  ('Morus', 'is a part of', 'family Moraceae'),
#  ('waul', 'is a', 'wail'),
#  ('sound camera', 'is a', 'motion-picture camera'),
#  ('hypothermia', 'is a', 'physical condition'),
#  ('Belgium', 'is a part of', 'EU'),
#  ('fly', 'is a', 'go'),
#  ('ketorolac', 'is made of', 'ethanoic acid'),
#  ('television system', 'is a', 'telecom system'),
#  ('differential', 'is a', 'pinion and ring gear'),
#  ('cut in', 'is a', 'blend in'),
#  ('den', 'is a part of', 'dwelling'),
#  ('blintze', 'is a', 'battercake'),
#  ('put down', 'is a', 'lay'),
#  ('baby', 'is a', 'missy'),
#  ('sundial', 'is a', 'horologe'),
#  ('Hyacinthoides', 'is a part of', 'family Liliaceae'),
#  ('fend', 'is a', 'manage'),
#  ('vellication', 'is a', 'muscle spasm'),
#  ('remold', 'is a', 'form'),
#  ('faqir', 'is a', 'saint'),
#  ('break with', 'is a', 'break'),
#  ('baggage', 'is a', 'adult female'),
#  ('tailfin', 'is a', 'stabilizer'),
#  ('foulard', 'is a', 'textile'),
#  ('youth culture', 'is a', 'generation'),
#  ('Pandanaceae', 'is a', 'monocot family'),
#  ('bog', 'is a', 'break off'),
#  ('genus Anatotitan', 'is a part of', 'family Hadrosauridae'),
#  ('cobble', 'is a', 'touch on'),
#  ('haematocrit', 'is a', 'centrifuge'),
#  ('boil', 'is a', 'be'),
#  ('flume', 'is a', 'gorge'),
#  ('chevy', 'is a', 'rile'),
#  ('lawmaker', 'is a', 'leader'),
#  ('accommodator', 'is a', 'helper'),
#  ('divergence', 'is a', 'variation'),
#  ('herpes genitalis', 'is a', 'venereal infection'),
#  ('applied science', 'is a', 'subject'),
#  ('politick', 'is a', 'pursue'),
#  ('caper family', 'is a part of', 'Papaverales'),
#  ('Anglian', 'is a', 'Anglo-Saxon'),
#  ('mint', 'is a', 'large indefinite quantity'),
#  ('invade', 'is a', 'go into'),
#  ('tackle', 'is a', 'attack'),
#  ('richness', 'is a', 'property'),
#  ('scorzonera', 'is a part of', 'scorzonera'),
#  ('compost heap', 'is a', 'cumulus'),
#  ('illume', 'is a', 'lighten'),
#  ('franc-tireur', 'is a', 'marksman'),
#  ('hat', 'is a', 'part'),
#  ('kneeling', 'is a', 'move'),
#  ('family Anacardiaceae', 'is a', 'dicot family'),
#  ('empty', 'is a', 'alter'),
#  ('blue point', 'is a part of', 'Ostrea'),
#  ('mainsail', 'is a', 'canvass'),
#  ('plagiarism', 'is a', 'piece of writing'),
#  ('Corchorus', 'is a part of', 'linden family'),
#  ('GA', 'is a part of', 'USA'),
#  ('proprietress', 'is a', 'proprietor'),
#  ('astringent drug', 'is a', 'medication'),
#  ('excavate', 'is a', 'core out'),
#  ('Strombidae', 'is a part of', 'class Gastropoda'),
#  ('genus Phalaris', 'is a part of', 'family Poaceae'),
#  ('Republic of Burundi', 'is a part of', 'Africa'),
#  ('subdivision Ginkgophytina', 'is a', 'class'),
#  ('paprika', 'is made of', 'paprika'),
#  ('plug', 'is a', 'promotion'),
#  ('expelling', 'is a', 'bodily process'),
#  ('nosepiece', 'is a part of', 'body armor'),
#  ('sable antelope', 'is a part of', 'Hippotragus'),
#  ('family Elaeocarpaceae', 'is a', 'dilleniid dicot family'),
#  ('naval brass', 'is a', 'Muntz metal'),
#  ('mortify', 'is a', 'mortify'),
#  ('Aplectrum', 'is a part of', 'Orchidaceae'),
#  ('Connaraceae', 'is a part of', 'Rosales'),
#  ('water lily', 'is a', 'water plant'),
#  ('aggrandise', 'is a', 'overdraw'),
#  ('Powhatan', 'is a', 'Algonquin'),
#  ('Gopher State', 'is a part of', 'USA'),
#  ('Entoprocta', 'is a', 'phylum'),
#  ('Hytrin', 'is a', 'alpha-adrenergic blocking agent'),
#  ('warrior', 'is a', 'soul'),
#  ('soliloquy', 'is a', 'voice communication'),
#  ('withy', 'is a', 'branchlet'),
#  ('makeup', 'is a', 'property'),
#  ('parquet floor', 'is a', 'floor'),
#  ('fraternise', 'is a', 'socialise'),
#  ('emaciate', 'is a', 'debilitate'),
#  ('toleration', 'is a', 'tolerance'),
#  ('irony', 'is a', 'humor'),
#  ('democracy', 'is a', 'philosophy'),
#  ('sniveler', 'is a', 'person'),
#  ('ID', 'is a part of', 'USA'),
#  ('family Empetraceae', 'is a part of', 'order Sapindales'),
#  ('hoop', 'is a', 'skeletal frame'),
#  ('occipital protuberance', 'is a part of', 'occipital bone'),
#  ('crepe', 'is a', 'hot cake'),
#  ('clostridial myonecrosis', 'is a', 'sphacelus'),
#  ('musjid', 'is a', 'house of prayer'),
#  ('thread maker', 'is a', 'maker'),
#  ('Ojibway', 'is a', 'Algonquin'),
#  ('order Diapensiales', 'is a part of', 'Magnoliopsida'),
#  ('choline', 'is a', 'vitamin B'),
#  ('therapeutic', 'is a', 'medication'),
#  ('alcoholic beverage', 'is a', 'drink'),
#  ('throb', 'is a', 'heartbeat'),
#  ('sand lizard', 'is a', 'lacertid'),
#  ('deary', 'is a', 'lover'),
#  ('genus Erigeron', 'is a part of', 'Compositae'),
#  ('lift off', 'is a', 'start'),
#  ('Buceros', 'is a', 'bird genus'),
#  ('supervisory routine', 'is a part of', 'supervisor'),
#  ('European dune grass', 'is a', 'lyme grass'),
#  ('frame', 'is a', 'give voice'),
#  ('odour', 'is a', 'sense datum'),
#  ('single', 'is a', 'figure'),
#  ('hyperpiesia', 'is a', 'high blood pressure'),
#  ('Japanese millet', 'is a part of', 'Echinochloa'),
#  ('chinch bug', 'is a part of', 'genus Blissus'),
#  ('mistletoe family', 'is a', 'dilleniid dicot family'),
#  ('tumbler', 'is a', 'drinking glass'),
#  ('foliate', 'is a', 'decorate'),
#  ('Thiobacteriaceae', 'is a part of', 'order Pseudomonadales'),
#  ('genus Kohleria', 'is a part of', 'Gesneriaceae'),
#  ('vest', 'is a', 'dress'),
#  ('moa', 'is a', 'ratite bird'),
#  ('Esox americanus', 'is a', 'pickerel'),
#  ('XXVIII', 'is a', 'large integer'),
#  ('parallelize', 'is a', 'set'),
#  ('feijoa', 'is a', 'bush'),
#  ('wind', 'is a', 'lace'),
#  ('select', 'is a', "make up one's mind"),
#  ('caucus', 'is a', 'meet'),
#  ('harikari', 'is a', 'self-annihilation'),
#  ('mark', 'is a', 'make'),
#  ('genus Micromyx', 'is a part of', 'Muridae'),
#  ('Prunella', 'is a part of', 'Labiatae'),
#  ('Lower-Normandy', 'is a part of', 'Normandy'),
#  ('quadriphonic system', 'is a', 'stereophony'),
#  ('Phalaris arundinacea', 'is a', 'grass'),
#  ('emphasis', 'is a', 'grandness'),
#  ('Coregonus artedi', 'is a', 'whitefish'),
#  ('time off', 'is a', 'period'),
#  ('fraud in the factum', 'is a', 'fraud'),
#  ('lockup', 'is a', 'clink'),
#  ('finback', 'is a', 'razorback'),
#  ('Alectura lathami', 'is a', 'mound-bird'),
#  ('the Flood', 'is a', 'flood'),
#  ('Lepus', 'is a part of', 'Leporidae'),
#  ('ball', 'is a part of', 'male genitalia'),
#  ('order Ranunculales', 'is a', 'plant order'),
#  ('traffic', 'is a', 'trade'),
#  ('interrogative mood', 'is a', 'modality'),
#  ('delusion', 'is a', 'mental state'),
#  ('effeminise', 'is a', 'change'),
#  ('beef', 'is a', 'complain'),
#  ('South Island', 'is a part of', 'New Zealand'),
#  ('rend', 'is a', 'snap'),
#  ('Kassite', 'is a', 'tongue'),
#  ('Matricaria oreades', 'is a part of', 'Tripleurospermum'),
#  ('GPA', 'is a', 'criterion'),
#  ('incoherency', 'is a', 'disconnectedness'),
#  ('fluoresceine', 'is a', 'dye'),
#  ('expire', 'is a', 'change state'),
#  ('Trachurus', 'is a part of', 'Carangidae'),
#  ('hemisphere', 'is a part of', 'earth'),
#  ('autophyte', 'is a', 'flora'),
#  ('hunter-gatherer', 'is a part of', 'hunting and gathering society'),
#  ('dearth', 'is a', 'scarceness'),
#  ('component', 'is a', 'section'),
#  ('fly', 'is a', 'head for the hills'),
#  ('Long Island', 'is a part of', 'New York'),
#  ('tall crowfoot', 'is a', 'goldcup'),
#  ('councilorship', 'is a', 'place'),
#  ('prothrombin', 'is a', 'clotting factor'),
#  ('New World anteater', 'is a part of', 'family Myrmecophagidae'),
#  ('redbelly', 'is a part of', 'genus Pseudemys'),
#  ('forefront', 'is a', 'front end'),
#  ('vinyl', 'is a', 'chemical group'),
#  ('party', 'is a part of', 'political system'),
#  ('piece of tail', 'is a', 'sexual intercourse'),
#  ('riddle', 'is a', 'stick'),
#  ('Rio Bravo', 'is a part of', 'USA'),
#  ('water closet', 'is a', 'bathroom'),
#  ('Kirghizstan', 'is a part of', 'CIS'),
#  ('fanny', 'is a', 'crotch'),
#  ('tympanitis', 'is a', 'redness'),
#  ('family Pertusariaceae', 'is a part of', 'Lichenes'),
#  ('bring up', 'is a', 'cite'),
#  ('cristobalite', 'is made of', 'silicon dioxide'),
#  ('Spirodela', 'is a part of', 'family Lemnaceae'),
#  ('operation', 'is a', 'computing'),
#  ('island', 'is a', 'earth'),
#  ('granadillo', 'is made of', 'cocuswood'),
#  ('Navy', 'is a', 'federal agency'),
#  ('Gospel', 'is a', 'sacred text'),
#  ('negative', 'is a', 'controvert'),
#  ('Raffia farinifera', 'is a part of', 'genus Raphia'),
#  ('genus Poephila', 'is a part of', 'Ploceidae'),
#  ('Dendroctonus rufipennis', 'is a part of', 'Dendroctonus'),
#  ('phalanx', 'is a', 'os'),
#  ('Coelenterata', 'is a part of', 'Metazoa'),
#  ('Daucus carota', 'is a', 'wildflower'),
#  ('livery', 'is a', 'tending'),
#  ('villus', 'is a', 'appendage'),
#  ('scapular', 'is a', 'plume'),
#  ('floodgate', 'is a part of', 'sluiceway'),
#  ('anchor', 'is a', 'fasten'),
#  ('Bureau of Alcohol Tobacco and Firearms', 'is a part of', 'Treasury'),
#  ('fail-safe', 'is a', 'mechanism'),
#  ('Sao Louis', 'is a part of', 'Brazil'),
#  ('cite', 'is a', 'acknowledge'),
#  ('NOAA', 'is a', 'bureau'),
#  ('springbuck', 'is a part of', 'Antidorcas'),
#  ('tiger', 'is a', 'cat'),
#  ('regression line', 'is a part of', 'regression analysis'),
#  ('hustle', 'is a', 'rumpus'),
#  ('longer', 'is a', 'someone'),
#  ('army tank', 'is a', 'armoured vehicle'),
#  ('make off', 'is a', 'flee'),
#  ('encroachment', 'is a', 'wrongful conduct'),
#  ('garboil', 'is a', 'kerfuffle'),
#  ('synovial joint', 'is a', 'articulatio'),
#  ('installing', 'is a', 'start'),
#  ('cup fungus', 'is a part of', 'Discomycetes'),
#  ('black archangel', 'is a', 'herbaceous plant'),
#  ('posseman', 'is a part of', 'posse'),
#  ('sebaceous follicle', 'is a part of', 'integumentary system'),
#  ('kosher', 'is a', 'nourishment'),
#  ('mishmash', 'is a', 'smorgasbord'),
#  ('oesophagogastric junction', 'is a', 'junction'),
#  ('forgiver', 'is a', 'soul'),
#  ('rapid climb', 'is a', 'ascension'),
#  ('lobbyism', 'is a', 'pattern'),
#  ('tetchiness', 'is a', 'fussiness'),
#  ('social dancer', 'is a', 'person'),
#  ('slop', 'is a', 'waste product'),
#  ('still', 'is a', 'suppress'),
#  ('placard', 'is a', 'sign'),
#  ('fume', 'is a', 'ooze out'),
#  ('Callinectes sapidus', 'is a part of', 'genus Callinectes'),
#  ('California tree poppy', 'is a part of', 'genus Romneya'),
#  ('avenger', 'is a', 'aggressor'),
#  ('nipper', 'is a', 'member'),
#  ('choroid plexus', 'is a', 'rete'),
#  ('theatregoer', 'is a', 'spectator'),
#  ('Columbus', 'is a part of', 'Ohio'),
#  ('National Oceanic and Atmospheric Administration',
#   'is a',
#   'government agency'),
#  ('Lateran', 'is a part of', 'Eternal City'),
#  ('genus Lesquerella', 'is a part of', 'family Cruciferae'),
#  ('monthly', 'is a', 'serial'),
#  ('epidermal cell', 'is a part of', 'epidermis'),
#  ('shell-flower', 'is a', 'bog plant'),
#  ('chicken scratch', 'is a', 'cacography'),
#  ('genus Swietinia', 'is a part of', 'Meliaceae'),
#  ('specific', 'is a', 'medicinal drug'),
#  ('water birch', 'is a part of', 'Betula'),
#  ('official emissary', 'is a part of', 'foreign mission'),
#  ('fairy godmother', 'is a', 'sprite'),
#  ('proprioception', 'is a part of', 'somesthesia'),
#  ('sea-purse', 'is a', 'undercurrent'),
#  ('veronal', 'is a', 'barbiturate'),
#  ('lock away', 'is a', 'confine'),
#  ('sea horse', 'is a', 'needlefish'),
#  ('dunce', 'is a', 'stupid person'),
#  ('snag', 'is a', 'gibbosity'),
#  ('Guayaquil', 'is a part of', 'Republic of Ecuador'),
#  ('western sandwich', 'is a', 'sandwich'),
#  ('publiciser', 'is a', 'communicator'),
#  ('tip', 'is a', 'strike'),
#  ('battle of the Bismarck Sea', 'is a part of', 'World War II'),
#  ('scyphozoan', 'is a', 'cnidarian'),
#  ('genus Orthotomus', 'is a part of', 'Sylviidae'),
#  ('reconcile', 'is a', 'adjust'),
#  ('bear', 'is a', 'clear'),
#  ('outcaste', 'is a', 'someone'),
#  ('compass saw', 'is a', "carpenter's saw"),
#  ('airing cupboard', 'is a', 'closet'),
#  ('magnetic induction', 'is a', 'natural action'),
#  ('neonatal mortality', 'is a', 'fatality rate'),
#  ('sales campaign', 'is a', 'ad campaign'),
#  ('drop-off', 'is a', 'formation'),
#  ('refurbishment', 'is a', 'improvement'),
#  ('romanticisation', 'is a', 'idealisation'),
#  ('attendant', 'is a', 'happening'),
#  ('fill', 'is a', 'take'),
#  ('internal-combustion engine', 'is a', 'heat engine'),
#  ('benefice', 'is a', 'dower'),
#  ('noctambulism', 'is a', 'sleeping'),
#  ('sibilant', 'is a', 'spirant'),
#  ('Chief Executive', 'is a', 'presidency'),
#  ('fold', 'is a', 'integrate'),
#  ('Richea dracophylla', 'is a part of', 'Richea'),
#  ('printer', 'is a', 'trained worker'),
#  ('Liberian capital', 'is a part of', 'Republic of Liberia'),
#  ('build', 'is a', 'amend'),
#  ('red fox', 'is a part of', 'genus Celosia'),
#  ('pressurize', 'is a', 'keep'),
#  ('Acanthocereus', 'is a part of', 'family Cactaceae'),
#  ('tussur', 'is a part of', 'Antheraea'),
#  ('take five', 'is a', 'intermit'),
#  ('spoke', 'is a part of', 'bicycle wheel'),
#  ('marinade', 'is a', 'steep'),
#  ('priming', 'is a', 'readying'),
#  ('coach dog', 'is a', 'Canis familiaris'),
#  ('thiamine', 'is a', 'vitamin B complex'),
#  ('Sylvilagus aquaticus', 'is a part of', 'genus Sylvilagus'),
#  ('pennant', 'is a', 'honour'),
#  ('Gothic romancer', 'is a', 'writer'),
#  ('ERA', 'is a', 'standard'),
#  ('showy lady slipper', 'is a', "ladies' slipper"),
#  ('heroism', 'is a', 'courageousness'),
#  ('anode', 'is a part of', 'accumulator'),
#  ('Bachelor of Naval Science', 'is a', 'baccalaureate'),
#  ('distill', 'is a', 'create'),
#  ('slugger', 'is a', 'ballplayer'),
#  ('track star', 'is a', 'star'),
#  ('Triatoma', 'is a', 'arthropod genus'),
#  ('Bassariscus astutus', 'is a part of', 'genus Bassariscus'),
#  ('indifference', 'is a', 'passiveness'),
#  ('tweak', 'is a', 'tune up'),
#  ('genus Adalia', 'is a', 'arthropod genus'),
#  ('inaugural', 'is a part of', 'inauguration'),
#  ('visualise', 'is a', 'envisage'),
#  ('Mekong River', 'is a part of', 'Siam'),
#  ('seismogram', 'is a', 'graphical record'),
#  ('saddle', 'is a', 'cut of meat'),
#  ('class-action suit', 'is a', 'lawsuit'),
#  ('the Pamirs', 'is a part of', 'mainland China'),
#  ('verifier', 'is a', 'booster'),
#  ('West', 'is a part of', 'United States of America'),
#  ('extract', 'is a', 'select'),
#  ('cause of death', 'is a', 'causal agency'),
#  ('Libyan Desert', 'is a part of', 'United Arab Republic'),
#  ('bastnaesite', 'is made of', 'atomic number 62'),
#  ('unconscious', 'is a', 'nous'),
#  ('pansexual', 'is a', 'someone'),
#  ('koruna', 'is a', 'Slovakian monetary unit'),
#  ('resolve', 'is a', 'calculate'),
#  ('fill', 'is a', 'furbish up'),
#  ('grippe', 'is a', 'respiratory disorder'),
#  ('overflow incontinence', 'is a', 'urinary incontinence'),
#  ('grime', 'is a', 'change'),
#  ('AAS', 'is a', 'associate'),
#  ('ribbonwood', 'is made of', 'New Zealand cotton'),
#  ('hangar', 'is a part of', 'drome'),
#  ('trust', 'is a', 'friendly relationship'),
#  ('manoeuver', 'is a', 'command'),
#  ('NIH', 'is a', 'federal agency'),
#  ('Tropidoclonion', 'is a', 'reptile genus'),
#  ('syncretise', 'is a', 'blend'),
#  ('standing rib roast', 'is a part of', 'rib'),
#  ('sensualness', 'is a', 'concupiscence'),
#  ('satin bird', 'is a part of', 'genus Ptilonorhynchus'),
#  ('atomic number 32', 'is a', 'chemical element'),
#  ('vasectomise', 'is a', 'desexualize'),
#  ('pearl', 'is a', 'sphere'),
#  ('genus Plectania', 'is a part of', 'family Pezizaceae'),
#  ('snorting', 'is a', 'expiration'),
#  ('High German', 'is a', 'West Germanic language'),
#  ('menage a trois', 'is a', 'household'),
#  ('military junta', 'is a', 'coterie'),
#  ('taste perception', 'is a', 'esthesis'),
#  ('carabiner', 'is a', 'ring'),
#  ('bloodroot', 'is a part of', 'Sanguinaria'),
#  ('gallimaufry', 'is a', 'salmagundi'),
#  ('Atropa belladonna', 'is a part of', 'Atropa'),
#  ('attachment', 'is a', 'heart'),
#  ('law of action and reaction', 'is a', "Newton's law"),
#  ('genus Psittacosaurus', 'is a', 'reptile genus'),
#  ('snail bean', 'is a', 'leguminous plant'),
#  ('leatherwork', 'is a', 'piece of work'),
#  ('barroom', 'is a part of', 'taphouse'),
#  ('have it coming', 'is a', 'deserve'),
#  ('chicle gum', 'is a', 'gum'),
#  ('Buteo', 'is a', 'bird genus'),
#  ('delude', 'is a', 'victimize'),
#  ('persimmon', 'is a part of', 'Diospyros kaki'),
#  ('refute', 'is a', 'disown'),
#  ('magnetic stripe', 'is a', 'tape'),
#  ('Georgia bark', 'is a', 'bush'),
#  ('mole rat', 'is a part of', 'genus Bathyergus'),
#  ('Slovenian', 'is a part of', 'Slovenija'),
#  ('Maha', 'is a', 'Dhegiha'),
#  ('jubilation', 'is a', 'affair'),
#  ('common land', 'is a', 'lea'),
#  ('stitchery', 'is a', 'needlecraft'),
#  ('Attacapan', 'is a', 'Plains Indian'),
#  ('Galveston', 'is a part of', 'Lone-Star State'),
#  ('dockage', 'is a part of', 'harbor'),
#  ('action mechanism', 'is a', 'mechanism'),
#  ('snarl', 'is a', 'speak'),
#  ('indian mustard', 'is a part of', 'genus Brassica'),
#  ('lawn cart', 'is a', 'pushcart'),
#  ('United Nations Educational Scientific and Cultural Organization',
#   'is a',
#   'UN agency'),
#  ('baby tears', 'is a part of', 'Helxine'),
#  ('arteria circumflexa humeri', 'is a part of', 'articulatio humeri'),
#  ('city state', 'is a', 'nation'),
#  ('Mountain State', 'is a part of', 'United States'),
#  ('trazodone', 'is a', 'nontricyclic drug'),
#  ('renal pelvis', 'is a', 'bodily cavity'),
#  ('close', 'is a', 'complete'),
#  ('Farm Credit System', 'is a', 'banking industry'),
#  ('inlet manifold', 'is a part of', 'petrol engine'),
#  ('Lancastrian line', 'is a', 'royalty'),
#  ('thread-fish', 'is a part of', 'genus Alectis'),
#  ('baseball player', 'is a', 'player'),
#  ('Bombax', 'is a part of', 'Bombacaceae'),
#  ('friendly', 'is a', 'troops'),
#  ('cosign', 'is a', 'formalise'),
#  ('genus Myosotis', 'is a part of', 'family Boraginaceae'),
#  ('thank', 'is a', 'convey'),
#  ('chelate', 'is a', 'heterocycle'),
#  ('fox-trot', 'is a', 'ballroom dancing'),
#  ('loving cup', 'is a', 'prize'),
#  ('scad', 'is a part of', 'family Carangidae'),
#  ('cerivastatin', 'is a', 'statin drug'),
#  ('pluviometer', 'is a', 'gauge'),
#  ('theater of operations', 'is a part of', 'theater of war'),
#  ('tutorship', 'is a', 'teaching'),
#  ('American Revolutionary leader', 'is a', 'nationalist leader'),
#  ('synchroniser', 'is a', 'measuring system'),
#  ('Korean velvet grass', 'is a', 'zoysia'),
#  ('Helsingfors', 'is a part of', 'Finland'),
#  ('Euphrates', 'is a part of', 'Republic of Turkey'),
#  ('design', 'is a', 'organization'),
#  ('milk wagon', 'is a', 'waggon'),
#  ('manifold', 'is a', 'paper'),
#  ('Zoomastigina', 'is a part of', 'class Flagellata'),
#  ('vulcanizer', 'is a', 'skilled workman'),
#  ('lay to rest', 'is a', 'put down'),
#  ('pamphlet', 'is a', 'book'),
#  ('duo', 'is a', 'musical composition'),
#  ('valuation reserve', 'is a', 'reserve fund'),
#  ('narcoleptic', 'is a', 'diseased person'),
#  ('infringe', 'is a', 'break'),
#  ('dynamite', 'is made of', 'Nitrostat'),
#  ('drepanocytic anemia', 'is a', 'anaemia'),
#  ('atomic number 19', 'is a', 'metallic element'),
#  ('flannel leaf', 'is a', 'herbaceous plant'),
#  ('hydrogenate', 'is a', 'alter'),
#  ('tonne', 'is a', 'metric weight unit'),
#  ('idiomatic expression', 'is a', 'expression'),
#  ('guest', 'is a', 'computing device'),
#  ('abstainer', 'is a', 'religious person'),
#  ('ore', 'is a part of', 'krone'),
#  ('canvass', 'is a part of', 'ring'),
#  ('tsatske', 'is a', 'collectable'),
#  ('Karnataka', 'is a part of', 'India'),
#  ('grand', 'is a', 'forte-piano'),
#  ('genus Potos', 'is a part of', 'family Procyonidae'),
#  ('describe', 'is a', 'set forth'),
#  ('genus Hardenbergia', 'is a part of', 'subfamily Papilionoideae'),
#  ('plosive speech sound', 'is a', 'obstruent'),
#  ('pyrolusite', 'is made of', 'atomic number 25'),
#  ('spin', 'is a', 'extend'),
#  ('hectolitre', 'is a part of', 'kiloliter'),
#  ('entente cordiale', 'is a', 'alignment'),
#  ('phylum Pyrrophyta', 'is a part of', 'Monera'),
#  ('goose barnacle', 'is a', 'cirriped'),
#  ('knife-handle', 'is a part of', 'genus Ensis'),
#  ('California whipsnake', 'is a', 'whip snake'),
#  ('famish', 'is a', 'kick the bucket'),
#  ('mitre box', 'is a', 'hand tool'),
#  ('ichor', 'is a', 'body fluid'),
#  ('one-fifth', 'is a', 'common fraction'),
#  ('throw-weight', 'is a', 'weight'),
#  ('damp-proof course', 'is a', 'course'),
#  ('whizbang', 'is a', 'banger'),
#  ('mouse eared chickweed', 'is a part of', 'Cerastium'),
#  ('name', 'is a', 'charge'),
#  ('Sonora semiannulata', 'is a', 'colubrid snake'),
#  ('fowl', 'is a', 'gallinaceous bird'),
#  ('labial pipe', 'is a', 'organ pipe'),
#  ("Addison's syndrome", 'is a', 'adenosis'),
#  ('X-linked recessive inheritance', 'is a', 'hereditary pattern'),
#  ('arrivederci', 'is a', 'word of farewell'),
#  ('villain', 'is a', 'persona non grata'),
#  ('Machaeranthera tortifoloia', 'is a', 'wild flower'),
#  ('quantification', 'is a', 'limitation'),
#  ('fawn', 'is a', 'blandish'),
#  ('North Germanic', 'is a', 'Germanic language'),
#  ('color', 'is a', 'timber'),
#  ('FORTRAN program', 'is a', 'computer programme'),
#  ('pedlar', 'is a', 'vendor'),
#  ('incaution', 'is a', 'sloppiness'),
#  ('Hirundinidae', 'is a part of', 'Passeres'),
#  ('text-matching', 'is a', 'programme'),
#  ('real number', 'is a', 'imaginary'),
#  ('haw', 'is a', 'utter'),
#  ('Asparagaceae', 'is a part of', 'family Liliaceae'),
#  ('Kniphofia uvaria', 'is a', 'kniphofia'),
#  ('genus Petromyzon', 'is a part of', 'family Petromyzontidae'),
#  ('sole', 'is a part of', 'Soleidae'),
#  ('underplay', 'is a', 'roleplay'),
#  ('lace bug', 'is a', 'plant bug'),
#  ('cystoparalysis', 'is a', 'palsy'),
#  ('soft-finned fish', 'is a part of', 'superorder Malacopterygii'),
#  ('firebomb', 'is a', 'bomb'),
#  ('Acridotheres tristis', 'is a', 'mynah'),
#  ('hue', 'is a', 'colorise'),
#  ('tread', 'is a', 'brace'),
#  ('obtain', 'is a', 'get'),
#  ('terebinth', 'is a part of', 'Pistacia'),
#  ('grab', 'is a', 'intrigue'),
#  ('ado', 'is a', 'ruction'),
#  ('reversible process', 'is a', 'physical process'),
#  ('dynamite', 'is made of', 'glyceryl trinitrate'),
#  ('genus Choeronycteris', 'is a part of', 'Phyllostomidae'),
#  ('mocha', 'is a', 'flavoring'),
#  ('blende', 'is made of', 'atomic number 49'),
#  ('commando', 'is a', 'military force'),
#  ('radial engine', 'is a', 'internal-combustion engine'),
#  ('hill', 'is a', 'mould'),
#  ('poppy mallow', 'is a part of', 'genus Callirhoe'),
#  ('superhet', 'is a', 'tuner'),
#  ('family Hydnoraceae', 'is a part of', 'Aristolochiales'),
#  ('peacock flower fence', 'is a', 'tree'),
#  ('work', 'is a', 'capture'),
#  ('veer', 'is a', 'turn'),
#  ('Firmiana simplex', 'is a', 'tree'),
#  ('white titi', 'is a', 'shrub'),
#  ('family Graminaceae', 'is a part of', 'order Graminales'),
#  ('Detroit River', 'is a part of', 'Great Lakes State'),
#  ('twayblade', 'is a part of', 'Listera'),
#  ('DTs', 'is a', 'psychosis'),
#  ('French telephone', 'is a', 'phone'),
#  ('Eternal City', 'is a part of', 'Italia'),
#  ('gutter', 'is a', 'feed'),
#  ('butchery', 'is a', 'building'),
#  ('rawness', 'is a', 'wholeness'),
#  ("Werlhof's disease", 'is a', 'autoimmune disease'),
#  ('Hypoxidaceae', 'is a part of', 'Liliales'),
#  ('sprouting', 'is a', 'development'),
#  ('order Coleoptera', 'is a part of', 'Hexapoda'),
#  ('China jute', 'is a part of', 'genus Abutilon'),
#  ('BuSpar', 'is a', 'anxiolytic'),
#  ('disregard', 'is a', 'do by'),
#  ('twinberry', 'is a part of', 'genus Lonicera'),
#  ('green dragon', 'is a part of', 'genus Dracunculus'),
#  ('quinnat salmon', 'is a', 'salmon'),
#  ('equal-area map projection', 'is a', 'map projection'),
#  ('Armenian alphabet', 'is a', 'alphabet'),
#  ('bonehead', 'is a', 'stupe'),
#  ('lead', 'is a', 'cause'),
#  ('anaerobic exercise', 'is a', 'exercising'),
#  ('tough', 'is a', 'assaulter'),
#  ('take advantage', 'is a', 'gain'),
#  ('Saint Francis River', 'is a part of', 'MO'),
#  ('waterweed', 'is a part of', 'genus Elodea'),
#  ('Welsh', 'is a', 'oxen'),
#  ('summer cypress', 'is a part of', 'genus Bassia'),
#  ('acknowledge', 'is a', 'pass'),
#  ('operational casualty', 'is a', 'damage'),
#  ('movement', 'is a', 'occurrence'),
#  ('factor', 'is a', 'calculate'),
#  ('nonindulgence', 'is a', 'self-denial'),
#  ('Don', 'is a', 'form of address'),
#  ('concreteness', 'is a', 'corporality'),
#  ('lamp housing', 'is a part of', 'cine projector'),
#  ('bee', 'is a', 'social affair'),
#  ('bring back', 'is a', 'take'),
#  ('approach pattern', 'is a', 'route'),
#  ('train', 'is a', 'check'),
#  ('family Onagraceae', 'is a part of', 'Myrtales'),
#  ('latent content', 'is a', 'content'),
#  ('ethnos', 'is a', 'grouping'),
#  ('Church Father', 'is a', 'theologist'),
#  ('sestet', 'is a', 'musical group'),
#  ('sand verbena', 'is a part of', 'Abronia'),
#  ('genus Oligoplites', 'is a part of', 'family Carangidae'),
#  ('Annonaceae', 'is a part of', 'order Ranunculales'),
#  ('frisking', 'is a', 'hunt'),
#  ('order Sphagnales', 'is a part of', 'class Musci'),
#  ('arnica', 'is a', 'herbaceous plant'),
#  ('jump off', 'is a', 'get'),
#  ('construct', 'is a', 'conjecture'),
#  ('cony', 'is a part of', 'family Procaviidae'),
#  ('Schefflera', 'is a part of', 'family Araliaceae'),
#  ('market', 'is a', 'socio-economic class'),
#  ('Passer montanus', 'is a part of', 'genus Passer'),
#  ('ask for', 'is a', 'evoke'),
#  ('overfly', 'is a', 'go'),
#  ('blab out', 'is a', 'divulge'),
#  ('cherry laurel', 'is a part of', 'genus Prunus'),
#  ('trill', 'is a', 'tone'),
#  ('Senora', 'is a', 'title'),
#  ('butt', 'is a', 'position'),
#  ('Python sebae', 'is a part of', 'genus Python'),
#  ('academician', 'is a', 'student'),
#  ('Vaudois', 'is a', 'sect'),
#  ('leave', 'is a', 'going'),
#  ("shank's pony", 'is a', 'leg'),
#  ('uncross', 'is a', 'unfold'),
#  ('hank panky', 'is a', 'carnal knowledge'),
#  ('flower girl', 'is a', 'girl'),
#  ('recruit', 'is a', 'register'),
#  ("prince's-feather", 'is a', 'subshrub'),
#  ('break in', 'is a', 'begin'),
#  ('retrovert', 'is a', 'turn'),
#  ('genus Felicia', 'is a part of', 'Compositae'),
#  ('tank engine', 'is a', 'railway locomotive'),
#  ('Alcyonaria', 'is a part of', 'class Anthozoa'),
#  ('pull-in', 'is a', 'coffeehouse'),
#  ('egality', 'is a', 'equality'),
#  ('Keystone State', 'is a part of', 'Mid-Atlantic states'),
#  ('imam', 'is a', 'Muslim'),
#  ('Wyoming', 'is a part of', 'U.S.'),
#  ('water back', 'is a', 'hot-water tank'),
#  ('Pteropogon humboltianum', 'is a', 'herb'),
#  ('Rudbeckia hirta', 'is a part of', 'Rudbeckia'),
#  ('closed-end fund', 'is a', 'investment firm'),
#  ('patrolman', 'is a', 'peace officer'),
#  ('cubic centimeter', 'is a', 'metric capacity unit'),
#  ('abort', 'is a', 'die'),
#  ('cerebral mantle', 'is made of', 'substantia grisea'),
#  ('Neobiotic', 'is a', 'antibiotic drug'),
#  ('semiotics', 'is a', 'philosophical theory'),
#  ('Turdus torquatus', 'is a', 'thrush'),
#  ('medicine', 'is a', 'treat'),
#  ('Hypocreales', 'is a part of', 'class Pyrenomycetes'),
#  ('form', 'is a part of', 'somebody'),
#  ('maiden aunt', 'is a', 'auntie'),
#  ('roughneck', 'is a', 'attacker'),
#  ('wheel bug', 'is a part of', 'genus Arilus'),
#  ('Diomedea exulans', 'is a', 'albatross'),
#  ('feast', 'is a', 'dinner party'),
#  ('alpha-naphthol test', 'is a', 'indicator'),
#  ('basinet', 'is a part of', 'body armor'),
#  ('creatine phosphoric acid', 'is a', 'organic compound'),
#  ('cox', 'is a', 'be'),
#  ('spiel', 'is a', 'line'),
#  ('upper cannon', 'is a part of', 'coat of mail'),
#  ("rogue's gallery", 'is a', 'ingroup'),
#  ('pyrrhuloxia', 'is a part of', 'genus Pyrrhuloxia'),
#  ('fair', 'is a', 'cut-rate sale'),
#  ('cubic millimeter', 'is a part of', 'ml'),
#  ('zero', 'is a', 'figure'),
#  ('grate', 'is a part of', 'range'),
#  ('ochre', 'is a', 'orange yellow'),
#  ('rate', 'is a', 'measure'),
#  ('necessary', 'is a', 'thing'),
#  ('Germany', 'is a part of', 'EC'),
#  ('Boxing Day', 'is a part of', 'Noel'),
#  ('scream', 'is a', 'outcry'),
#  ('regression curve', 'is a part of', 'regression analysis'),
#  ('Centropristis', 'is a part of', 'family Serranidae'),
#  ('crapper', 'is a part of', 'privy'),
#  ('position', 'is a', 'lay'),
#  ('fibre bundle', 'is a part of', 'nervous system'),
#  ('island', 'is a', 'terra firma'),
#  ('schmoose', 'is a', 'chew the fat'),
#  ('hero', 'is a', 'part'),
#  ('whipstitching', 'is a', 'embroidery stitch'),
#  ("Saint Elmo's fire", 'is a', 'electric discharge'),
#  ('outguess', 'is a', 'anticipate'),
#  ('bilk', 'is a', 'forbid'),
#  ('service man', 'is a', 'mender'),
#  ('festering', 'is a', 'bodily fluid'),
#  ('family Chrysopidae', 'is a part of', 'Neuroptera'),
#  ('genus Rheum', 'is a', 'magnoliopsid genus'),
#  ('celoma', 'is a', 'cavum'),
#  ('de-ionate', 'is a', 'take away'),
#  ('honour', 'is a', 'sexual morality'),
#  ('presage', 'is a', 'foretoken'),
#  ('foetal distress', 'is a', 'abnormality'),
#  ('hexameter', 'is a', 'verse line'),
#  ('horse wrangler', 'is a', 'cattleman'),
#  ('postdoc', 'is a', 'student'),
#  ('bank draft', 'is a', 'order of payment'),
#  ('Piper', 'is a part of', 'pepper family'),
#  ('constitutionalism', 'is a', 'political theory'),
#  ('borsht circuit', 'is a', 'playground'),
#  ('Prunus glandulosa', 'is a', 'almond tree'),
#  ('flyfish', 'is a', 'angle'),
#  ('Toxotes', 'is a part of', 'Toxotidae'),
#  ('raft foundation', 'is a', 'foot'),
#  ('Leontopodium', 'is a', 'asterid dicot genus'),
#  ('concrete', 'is made of', 'cement'),
#  ('colour', 'is a', 'decorate'),
#  ('Scarabaeus sacer', 'is a part of', 'genus Scarabaeus'),
#  ('child prodigy', 'is a', 'kid'),
#  ('interdict', 'is a', 'animadversion'),
#  ('tzetze', 'is a part of', 'genus Glossina'),
#  ('double-dealing', 'is a', 'dissembling'),
#  ('die', 'is a', 'lose it'),
#  ('genus Berteroa', 'is a part of', 'family Brassicaceae'),
#  ('bullnose', 'is a', 'woodworking plane'),
#  ('anise', 'is a part of', 'anise'),
#  ('inconvenience oneself', 'is a', 'reach'),
#  ('siamang', 'is a part of', 'Hylobates'),
#  ('mane', 'is a part of', 'homo'),
#  ('take it on the chin', 'is a', 'miscarry'),
#  ('atomic number 52', 'is a', 'chemical element'),
#  ('Lardizabalaceae', 'is a part of', 'order Ranales'),
#  ('chickpea plant', 'is a', 'leguminous plant'),
#  ('midway', 'is a', 'parcel of land'),
#  ('cure-all', 'is a', 'remedy'),
#  ('tallis', 'is a', 'shawl'),
#  ('proof spirit', 'is a', 'alcoholic beverage'),
#  ('bluster', 'is a', 'blow'),
#  ('compressing', 'is a', 'pressing'),
#  ('turn a blind eye', 'is a', 'brush aside'),
#  ('Libyan Desert', 'is a part of', 'Libya'),
#  ('deadeye', 'is a', 'disc'),
#  ('tank suit', 'is a', 'swimsuit'),
#  ('dance orchestra', 'is a', 'musical group'),
#  ('strong breeze', 'is a', 'air'),
#  ('Euphausiacea', 'is a', 'animal order'),
#  ('astrologist', 'is a', 'forecaster'),
#  ('catch', 'is a', 'watch'),
#  ('word-worship', 'is a', 'veneration'),
#  ('TOPV', 'is a', 'poliovirus vaccine'),
#  ('lemongrass', 'is a', 'oil'),
#  ("Golgi's cell", 'is a part of', 'pallium'),
#  ('11 November', 'is a part of', 'November'),
#  ('travail', 'is a part of', 'pregnancy'),
#  ('overrefine', 'is a', 'polish'),
#  ('awning deck', 'is a', 'deck'),
#  ('eternity', 'is a', 'interval'),
#  ('pedestrian', 'is a', 'traveller'),
#  ('New Scotland Yard', 'is a', 'constabulary'),
#  ('hotel manager', 'is a', 'decision maker'),
#  ('Glaswegian', 'is a', 'Scotsman'),
#  ('Portunidae', 'is a part of', 'Brachyura'),
#  ('lubber line', 'is a', 'point of reference'),
#  ('copper', 'is a', 'officer'),
#  ('double time', 'is a', 'salary'),
#  ('concurrent negligence', 'is a', 'carelessness'),
#  ('ostracize', 'is a', 'exclude'),
#  ('Delphi', 'is a part of', 'Ellas'),
#  ('Leyte Island', 'is a part of', 'Second World War'),
#  ('Distinguished Service Order', 'is a', 'palm'),
#  ('West Malaysia', 'is a part of', 'Malaya'),
#  ('hospitalization', 'is a', 'medical aid'),
#  ('spring', 'is a', 'unwrap'),
#  ('vertical file', 'is a', 'filing cabinet'),
#  ('family Peridiniidae', 'is a', 'protoctist family'),
#  ('name calling', 'is a', 'traducement'),
#  ('jellyfish', 'is a part of', 'phylum Cnidaria'),
#  ('souther', 'is a', 'wind'),
#  ('run off', 'is a', 'go forth'),
#  ('orchiopexy', 'is a', 'surgery'),
#  ('Callimorpha jacobeae', 'is a part of', 'Callimorpha'),
#  ('jump', 'is a', 'travel'),
#  ('resist', 'is a', 'escape'),
#  ('magnesite', 'is made of', 'atomic number 12'),
#  ('colouration', 'is a', 'colour'),
#  ('heat', 'is a', 'elicit'),
#  ('Green Mountain State', 'is a part of', 'U.S.A.'),
#  ('Cladrastis kentukea', 'is a part of', 'genus Cladrastis'),
#  ('gasolene', 'is a', 'hydrocarbon'),
#  ('family Menyanthaceae', 'is a part of', 'order Gentianales'),
#  ('slowworm', 'is a part of', 'genus Anguis'),
#  ('cyanocobalamin', 'is a', 'B-complex vitamin'),
#  ('genus Lanius', 'is a part of', 'Laniidae'),
#  ('tallith', 'is a', 'shawl'),
#  ('metalwork', 'is a', 'formation'),
#  ('puff up', 'is a', 'praise'),
#  ('newspaper advertisement', 'is a', 'ad'),
#  ('buffet', 'is a', 'strike'),
#  ('redeposit', 'is a', 'wedge'),
#  ('Theropoda', 'is a part of', 'suborder Sauropodomorpha'),
#  ('symbolic logician', 'is a', 'logistician'),
#  ('better half', 'is a', 'significant other'),
#  ('Gelechia', 'is a part of', 'family Gelechiidae'),
#  ('medusa', 'is a part of', 'phylum Cnidaria'),
#  ('aesthesia', 'is a', 'consciousness'),
#  ('Marburg disease', 'is a', 'haemorrhagic fever'),
#  ('bearer', 'is a', 'griever'),
#  ('jugglery', 'is a', 'wile'),
#  ('Angora', 'is a', 'Capra hircus'),
#  ('caravan', 'is a', 'motor home'),
#  ('desperation', 'is a', 'condition'),
#  ('interference', 'is a', 'act'),
#  ('see eye to eye', 'is a', 'hold'),
#  ('anagnost', 'is a', 'Order'),
#  ('political donation', 'is a', 'contribution'),
#  ('jeune fille', 'is a', 'young lady'),
#  ('family Oriolidae', 'is a part of', 'Passeres'),
#  ('gainer', 'is a', 'soul'),
#  ('telfer', 'is a', 'transport'),
#  ('family Trypetidae', 'is a', 'arthropod family'),
#  ('Seyhan River', 'is a part of', 'Republic of Turkey'),
#  ('fiddle', 'is a', 'play'),
#  ('rigourousness', 'is a', 'strictness'),
#  ('Lagostomus maximus', 'is a', 'gnawer'),
#  ('primary color for light', 'is a', 'primary color'),
#  ('forget', 'is a', 'leave out'),
#  ('genus Danaea', 'is a part of', 'family Marattiaceae'),
#  ('passer', 'is a', 'somebody'),
#  ('bus stop', 'is a part of', 'bus route'),
#  ('rank', 'is a part of', 'organisation'),
#  ('mark down', 'is a', 'shave'),
#  ('connection', 'is a', 'transport'),
#  ('redundancy check', 'is a', 'verification'),
#  ('baccy', 'is a', 'street drug'),
#  ('voucher', 'is a', 'friend'),
#  ('Paradoxurus', 'is a part of', 'Viverrinae'),
#  ('cyrilla', 'is a', 'bush'),
#  ('Pholas', 'is a part of', 'Pholadidae'),
#  ('syncretise', 'is a', 'mix'),
#  ('backtalk', 'is a', 'riposte'),
#  ('American gray birch', 'is a', 'birch'),
#  ('complication', 'is a', 'interference'),
#  ('execrate', 'is a', 'hate'),
#  ('overachieve', 'is a', 'do'),
#  ("pull someone's leg", 'is a', 'cozen'),
#  ('threaten', 'is a', 'portend'),
#  ('brainpan', 'is a', 'os'),
#  ('dual carriageway', 'is a', 'highway'),
#  ('orthoepy', 'is a', 'voice communication'),
#  ('rubric', 'is a', 'rubify'),
#  ('come off', 'is a', 'hap'),
#  ('set', 'is a', 'gear up'),
#  ('famine', 'is a', 'cataclysm'),
#  ('anti-torque rotor', 'is a', 'rotor'),
#  ('blate', 'is a', 'let out'),
#  ('twit', 'is a', 'simple'),
#  ('narrowboat', 'is a', 'boat'),
#  ('adenohypophysis', 'is a', 'endocrine gland'),
#  ('seif dune', 'is a', 'sand dune'),
#  ('bandy', 'is a', 'discuss'),
#  ('Uzi', 'is a', 'submachine gun'),
#  ('mislay', 'is a', 'put'),
#  ('glass', 'is a', 'upper'),
#  ('acrylonitrile-butadiene-styrene', 'is a', 'plastic'),
#  ('United States', 'is a part of', 'NATO'),
#  ('situation', 'is a', 'job'),
#  ('Hylobates lar', 'is a part of', 'genus Hylobates'),
#  ('lobe', 'is a part of', 'leafage'),
#  ('kangaroo rat', 'is a part of', 'Dipodomys'),
#  ('disembark', 'is a', 'land'),
#  ('Foreign Intelligence Surveillance Court', 'is a', 'tribunal'),
#  ('estragon', 'is a part of', 'tarragon'),
#  ('plate', 'is a', 'complex body part'),
#  ('family Pristidae', 'is a part of', 'order Batoidei'),
#  ('capitalist economy', 'is a', 'laissez-faire economy'),
#  ('pineal body', 'is a', 'endocrine gland'),
#  ('slip', 'is a', 'bloomer'),
#  ('deliquesce', 'is a', 'melt'),
#  ('orthopteron', 'is a part of', 'order Orthoptera'),
#  ('superorder Acanthopterygii', 'is a part of', 'Teleostei'),
#  ('coral-wood', 'is a part of', 'Adenanthera'),
#  ('broom palm', 'is a part of', 'genus Thrinax'),
#  ("Wernicke's area", 'is a part of', 'language zone'),
#  ('saloon', 'is a', 'tavern'),
#  ('genus Bouteloua', 'is a part of', 'grass family'),
#  ('consumer price index', 'is a', 'price level'),
#  ('helping hand', 'is a', 'assist'),
#  ('walk-up apartment', 'is a', 'flat'),
#  ('pass away', 'is a', 'change state'),
#  ('Paris green', 'is a', 'viridity'),
#  ('order Ephemeroptera', 'is a part of', 'Hexapoda'),
#  ('Anti-Masonic Party', 'is a', 'party'),
#  ('resurge', 'is a', 'develop'),
#  ('Cordyline', 'is a part of', 'Agavaceae'),
#  ('artichoke', 'is a part of', 'Cynara'),
#  ('king crab', 'is a part of', 'genus Maia'),
#  ('Picus viridis', 'is a', 'peckerwood'),
#  ('cattleman', 'is a', 'stock farmer'),
#  ('shallot', 'is a part of', 'eschalot'),
#  ('determine', 'is a', 'cause'),
#  ('bath', 'is a part of', 'dwelling'),
#  ('middle', 'is a part of', 'trunk'),
#  ('wellpoint', 'is a', 'tube'),
#  ('moose-wood', 'is a', 'maple'),
#  ('family Argentinidae', 'is a part of', 'order Isospondyli'),
#  ('let the cat out of the bag', 'is a', 'let out'),
#  ('high quality', 'is a', 'caliber'),
#  ('Old World porcupine', 'is a', 'porcupine'),
#  ('reassign', 'is a', 'designate'),
#  ('solemnize', 'is a', 'tie'),
#  ('ire', 'is a', 'mortal sin'),
#  ('course', 'is a', 'alimentation'),
#  ('alert', 'is a', 'preparation'),
#  ('sextet', 'is a', 'digit'),
#  ('small hours', 'is a', 'time of day'),
#  ('uncross', 'is a', 'open'),
#  ('food for thought', 'is a', 'cognitive content'),
#  ('San Joaquin River', 'is a part of', 'California'),
#  ('recorder', 'is a', 'official'),
#  ('detergent builder', 'is a', 'material'),
#  ('Kivu', 'is a part of', 'Ruanda'),
#  ('Yellow River', 'is a part of', 'China'),
#  ('metacarpal bone', 'is a part of', 'metacarpus'),
#  ('February 2', 'is a part of', 'February'),
#  ('Sumerology', 'is a', 'archeology'),
#  ('monogenic disease', 'is a', 'genetic disorder'),
#  ('hypostasis', 'is a', 'marrow'),
#  ('calabar-bean vine', 'is a part of', 'Physostigma'),
#  ('fund', 'is a', 'collect'),
#  ('genus Diceros', 'is a', 'mammal genus'),
#  ('pigeon breast', 'is a', 'misshapenness'),
#  ('dedicate', 'is a', 'use'),
#  ('Dieffenbachia', 'is a part of', 'arum family'),
#  ('Sierra Madre Oriental', 'is a part of', 'Mexico'),
#  ('quadroon', 'is a', 'mixed-blood'),
#  ('genus Sloanea', 'is a part of', 'elaeocarpus family'),
#  ('prophylactic', 'is a', 'remedy'),
#  ('glomerulus', 'is a part of', 'malpighian body'),
#  ('fer-de-lance', 'is a', 'pit viper'),
#  ('aloe family', 'is a part of', 'lily family'),
#  ('Cinchona pubescens', 'is a', 'chinchona'),
#  ('Trigonella', 'is a part of', 'Papilionoideae'),
#  ('run into', 'is a', 'hit'),
#  ('maidenhair fern', 'is a', 'fern'),
#  ('run aground', 'is a', 'make'),
#  ('giving birth', 'is a', 'biological process'),
#  ('podocarp', 'is a part of', 'genus Podocarpus'),
#  ('cranberry tree', 'is a', 'shrub'),
#  ('defacement', 'is a', 'scathe'),
#  ('knight of the square flag', 'is a', 'knight'),
#  ('laurel willow', 'is a part of', 'genus Salix'),
#  ('vino', 'is a', 'alcoholic beverage'),
#  ('regress', 'is a', 'turn back'),
#  ('warm to', 'is a', 'take'),
#  ('genus Troglodytes', 'is a part of', 'family Troglodytidae'),
#  ('wafer', 'is a', 'breadstuff'),
#  ('singultus', 'is a', 'reflex'),
#  ('division Lichenes', 'is a part of', 'kingdom Fungi'),
#  ('corrugate', 'is a', 'fold up'),
#  ('beat', 'is a', 'play'),
#  ('genus Deinocheirus', 'is a', 'reptile genus'),
#  ('beat a retreat', 'is a', 'quit'),
#  ('twenty percent', 'is a', 'common fraction'),
#  ('Rhodophyta', 'is a', 'division'),
#  ('Westminster', 'is a part of', 'capital of the United Kingdom'),
#  ('crayfish', 'is a part of', 'crayfish'),
#  ('genus Cuscuta', 'is a part of', 'Convolvulaceae'),
#  ('Fouquieriaceae', 'is a part of', 'order Parietales'),
#  ('cloister', 'is a', 'surround'),
#  ('Limonium', 'is a', 'dicot genus'),
#  ('hippy', 'is a part of', 'hipsters'),
#  ('tenant', 'is a', 'dwell'),
#  ('silver', 'is a', 'colourise'),
#  ('mussel shrimp', 'is a part of', 'subclass Ostracoda'),
#  ('Lowlander', 'is a', 'Scotsman'),
#  ('squirrel monkey', 'is a', 'platyrrhine'),
#  ('Hyphantria', 'is a part of', 'family Lasiocampidae'),
#  ('genus Fremontodendron', 'is a part of', 'Sterculiaceae'),
#  ('aneurin', 'is a', 'vitamin B complex'),
#  ('bulb', 'is a', 'stem'),
#  ('autonomic nervous system', 'is a part of', 'systema nervosum'),
#  ('misoneism', 'is a', 'hatred'),
#  ('belted kingfisher', 'is a part of', 'genus Ceryle'),
#  ('striped maple', 'is a', 'maple'),
#  ("Saint Ulmo's light", 'is a', 'electric discharge'),
#  ('looker', 'is a', 'percipient'),
#  ('transubstantiate', 'is a', 'alter'),
#  ('cannibalize', 'is a', 'take'),
#  ('Bessera elegans', 'is a part of', 'genus Bessera'),
#  ('sweat room', 'is a', 'vapor bath'),
#  ('Lafayette', 'is a part of', 'IN'),
#  ('sensitiveness', 'is a', 'sentiency'),
#  ('international organization', 'is a', 'alliance'),
#  ('beading', 'is a', 'moulding'),
#  ('frame of mind', 'is a', 'mental condition'),
#  ('order Procellariiformes', 'is a part of', 'class Aves'),
#  ('amusement park', 'is a', 'common'),
#  ('freeze-drying', 'is a', 'drying up'),
#  ("cash in one's chips", 'is a', 'turn'),
#  ...}

# %% [markdown]
# ## Only source 1 has it

# %%
len(set(f1_triples)-set(f2_triples))
# Out:
# 3261915
