# %% [markdown]
# ## Documentation

# %% [markdown]
# `AnnoyIndex(f, metric)`returns a new index that's read-write and stores vector of f dimensions. Metric can be "angular", "euclidean", "manhattan", "hamming", or "dot".
#
# `a.add_item(i, v)` adds item i (any nonnegative integer) with vector v. Note that it will allocate memory for max(i)+1 items.
#
# `a.build(n_trees, n_jobs=-1)` builds a forest of n_trees trees. More trees gives higher precision when querying. After calling build, no more items can be added. n_jobs specifies the number of threads used to build the trees. n_jobs=-1 uses all available CPU cores.
#
# `a.save(fn, prefault=False)` saves the index to disk and loads it (see next function). After saving, no more items can be added.
#
# `a.load(fn, prefault=False)` loads (mmaps) an index from disk. If prefault is set to True, it will pre-read the entire file into memory (using mmap with MAP_POPULATE). Default is False.
#
# `a.unload()` unloads.
#
# `a.get_nns_by_item(i, n, search_k=-1, include_distances=False)` returns the n closest items. During the query it will inspect up to search_k nodes which defaults to n_trees * n if not provided. search_k gives you a run-time tradeoff between better accuracy and speed. If you set include_distances to True, it will return a 2 element tuple with two lists in it: the second one containing all corresponding distances.
#
# `a.get_nns_by_vector(v, n, search_k=-1, include_distances=False)` same but query by vector v.
#
# `a.get_item_vector(i)` returns the vector for item i that was previously added.
#
# `a.get_distance(i, j)` returns the distance between items i and j. NOTE: this used to return the squared distance, but has been changed as of Aug 2016.
#
# `a.get_n_items()` returns the number of items in the index.
#
# `a.get_n_trees()` returns the number of trees in the index.
#
# `a.on_disk_build(fn)` prepares annoy to build the index in the specified file instead of RAM (execute before adding items, no need to save after build)
#
# `a.set_seed(seed)` will initialize the random number generator with the given seed. Only used for building up the tree, i. e. only necessary to pass this before adding the items. Will have no effect after calling a.build(n_trees) or a.load(fn).

# %% [markdown]
# ## Import library

# %%
from annoy import AnnoyIndex

# %% [markdown]
# ## Prepare Data and Index

# %%
# specify a certain entity embedding tsv file
input_file = '/nas/home/binzhang/backup_data/complex/comp_log_dot_0.01/entities_output.tsv'

# %%
# build a entity name-index bi dictionary
entity_dict = {}  # {name1:0, 0:name1}

# entity dimension
dimension = 100  

# build an index that stores vector
annoy_index = AnnoyIndex(dimension, 'angular')  # angular => cos

# %%
# %%time
with open(input_file, 'r') as f:
    for index,line in enumerate(f):
        line = line.split('\t')
        entity_name = line[0]
        entity_vec =  [ float(i) for i in line[1:]]
        entity_dict[entity_name] = index
        entity_dict[index] = entity_name
        annoy_index.add_item(index, entity_vec)
# Out:
# CPU times: user 55.6 s, sys: 1.29 s, total: 56.9 s
# Wall time: 56.9 s

# %%
# builds a forest of n_trees trees. More trees gives higher precision when querying. 
annoy_index.build(100) # build(n_trees, n_jobs=-1)
# Out:
# True

# %% [markdown]
# ## Get topk entites

# %%
entity_dict
# Out:
# {'/c/en/one_drives': 0,
#  0: '/c/en/one_drives',
#  '/c/en/nip_outs/n': 1,
#  1: '/c/en/nip_outs/n',
#  '/c/en/waycasters/n': 2,
#  2: '/c/en/waycasters/n',
#  'at:to_buy_a_similar_shirt': 3,
#  3: 'at:to_buy_a_similar_shirt',
#  '/c/en/eagar': 4,
#  4: '/c/en/eagar',
#  '/c/en/vesperate': 5,
#  5: '/c/en/vesperate',
#  '/c/en/favorableness/n/wn/attribute': 6,
#  6: '/c/en/favorableness/n/wn/attribute',
#  '/c/en/irenical/a': 7,
#  7: '/c/en/irenical/a',
#  '/c/en/except_in_eke_out': 8,
#  8: '/c/en/except_in_eke_out',
#  '/c/en/connecting_hose': 9,
#  9: '/c/en/connecting_hose',
#  '/c/en/adic/a': 10,
#  10: '/c/en/adic/a',
#  '/c/en/antirhinoviral/a': 11,
#  11: '/c/en/antirhinoviral/a',
#  '/c/en/finding_fishing_place': 12,
#  12: '/c/en/finding_fishing_place',
#  '/c/en/channery/a': 13,
#  13: '/c/en/channery/a',
#  '/c/en/snow_stage': 14,
#  14: '/c/en/snow_stage',
#  '/c/en/dubkis/n': 15,
#  15: '/c/en/dubkis/n',
#  '/c/en/stephanomeria_malheurensis/n/wn/plant': 16,
#  16: '/c/en/stephanomeria_malheurensis/n/wn/plant',
#  "at:ask_persony's_landlord_something": 17,
#  17: "at:ask_persony's_landlord_something",
#  '/c/en/stony/a': 18,
#  18: '/c/en/stony/a',
#  '/c/en/unfortunates/n': 19,
#  19: '/c/en/unfortunates/n',
#  '/c/en/effectible/a': 20,
#  20: '/c/en/effectible/a',
#  '/c/en/cupboard_love': 21,
#  21: '/c/en/cupboard_love',
#  'at:to_have_lost_something_dear': 22,
#  22: 'at:to_have_lost_something_dear',
#  '/c/en/open_rectangle/n': 23,
#  23: '/c/en/open_rectangle/n',
#  '/c/en/aftersee': 24,
#  24: '/c/en/aftersee',
#  '/c/en/kc/n': 25,
#  25: '/c/en/kc/n',
#  '/c/en/hultquists/n': 26,
#  26: '/c/en/hultquists/n',
#  '/c/en/hanging_plants': 27,
#  27: '/c/en/hanging_plants',
#  '/c/en/tati/n/wn/person': 28,
#  28: '/c/en/tati/n/wn/person',
#  '/c/en/tubae/n': 29,
#  29: '/c/en/tubae/n',
#  '/c/en/altoists/n': 30,
#  30: '/c/en/altoists/n',
#  '/c/en/cognovit_clauses/n': 31,
#  31: '/c/en/cognovit_clauses/n',
#  '/c/en/rebooking': 32,
#  32: '/c/en/rebooking',
#  '/c/en/secretomics': 33,
#  33: '/c/en/secretomics',
#  '/c/en/know_where_class': 34,
#  34: '/c/en/know_where_class',
#  '/c/en/isogeotherms/n': 35,
#  35: '/c/en/isogeotherms/n',
#  '/c/en/break/n/wikt/en_2': 36,
#  36: '/c/en/break/n/wikt/en_2',
#  '/c/en/foster_mothers/n': 37,
#  37: '/c/en/foster_mothers/n',
#  '/c/en/ichthyosporid/n': 38,
#  38: '/c/en/ichthyosporid/n',
#  '/c/en/drink_soup': 39,
#  39: '/c/en/drink_soup',
#  '/c/en/grey_platelet_syndrome/n': 40,
#  40: '/c/en/grey_platelet_syndrome/n',
#  '/c/en/downloadability': 41,
#  41: '/c/en/downloadability',
#  '/c/en/de_allergize': 42,
#  42: '/c/en/de_allergize',
#  '/c/en/selenic/a': 43,
#  43: '/c/en/selenic/a',
#  '/c/en/eat_out': 44,
#  44: '/c/en/eat_out',
#  '/c/en/beaten_track': 45,
#  45: '/c/en/beaten_track',
#  '/c/en/capsule': 46,
#  46: '/c/en/capsule',
#  '/c/en/liveforever/n': 47,
#  47: '/c/en/liveforever/n',
#  '/c/en/turn_calculator_off': 48,
#  48: '/c/en/turn_calculator_off',
#  '/c/en/agco': 49,
#  49: '/c/en/agco',
#  '/c/en/pakuls/n': 50,
#  50: '/c/en/pakuls/n',
#  'at:lower_credit_scores': 51,
#  51: 'at:lower_credit_scores',
#  'at:a_sense_of_longing': 52,
#  52: 'at:a_sense_of_longing',
#  '/c/en/manzamines/n': 53,
#  53: '/c/en/manzamines/n',
#  '/c/en/newborn_medical_specialist/n': 54,
#  54: '/c/en/newborn_medical_specialist/n',
#  '/c/en/something_is': 55,
#  55: '/c/en/something_is',
#  '/c/en/chickenwort/n': 56,
#  56: '/c/en/chickenwort/n',
#  '/c/en/cholecystokinin/n/wn/body': 57,
#  57: '/c/en/cholecystokinin/n/wn/body',
#  'at:not_look_where_they_are_going': 58,
#  58: 'at:not_look_where_they_are_going',
#  'at:another_piece_of_bread': 59,
#  59: 'at:another_piece_of_bread',
#  '/c/en/high_horses/n': 60,
#  60: '/c/en/high_horses/n',
#  '/c/en/choke_chain/n': 61,
#  61: '/c/en/choke_chain/n',
#  '/c/en/stupidass': 62,
#  62: '/c/en/stupidass',
#  'Q581730': 63,
#  63: 'Q581730',
#  '/c/en/mirror_carps/n': 64,
#  64: '/c/en/mirror_carps/n',
#  "at:personx_secures_persony's_release": 65,
#  65: "at:personx_secures_persony's_release",
#  '/c/en/amylostatin/n': 66,
#  66: '/c/en/amylostatin/n',
#  '/c/en/found_in_schools': 67,
#  67: '/c/en/found_in_schools',
#  '/c/en/field_poppy': 68,
#  68: '/c/en/field_poppy',
#  '/c/en/oral_sex': 69,
#  69: '/c/en/oral_sex',
#  'at:to_explore_a_new_place': 70,
#  70: 'at:to_explore_a_new_place',
#  '/c/en/polygynies/n': 71,
#  71: '/c/en/polygynies/n',
#  "at:personx's_memory_is_strengthened_due_to_the_memorization_of_sheet_music": 72,
#  72: "at:personx's_memory_is_strengthened_due_to_the_memorization_of_sheet_music",
#  '/c/en/shucker': 73,
#  73: '/c/en/shucker',
#  '/c/en/axe_small': 74,
#  74: '/c/en/axe_small',
#  '/c/en/bulwarks/n/wn/artifact': 75,
#  75: '/c/en/bulwarks/n/wn/artifact',
#  '/c/en/pollax': 76,
#  76: '/c/en/pollax',
#  '/c/en/have_to_drink': 77,
#  77: '/c/en/have_to_drink',
#  '/c/en/chicken_breasted/a': 78,
#  78: '/c/en/chicken_breasted/a',
#  '/c/en/prehabilitation/n': 79,
#  79: '/c/en/prehabilitation/n',
#  '/c/en/outdacious': 80,
#  80: '/c/en/outdacious',
#  '/c/en/dipaschal': 81,
#  81: '/c/en/dipaschal',
#  '/c/en/samolus_parviflorus/n/wn/plant': 82,
#  82: '/c/en/samolus_parviflorus/n/wn/plant',
#  '/c/en/eyewinks/n': 83,
#  83: '/c/en/eyewinks/n',
#  'at:read_the_review': 84,
#  84: 'at:read_the_review',
#  '/c/en/unexpectantly': 85,
#  85: '/c/en/unexpectantly',
#  '/c/en/retrocedent/a': 86,
#  86: '/c/en/retrocedent/a',
#  '/c/en/eating_at_restruant': 87,
#  87: '/c/en/eating_at_restruant',
#  '/c/en/afflecks/n': 88,
#  88: '/c/en/afflecks/n',
#  'Q47456921': 89,
#  89: 'Q47456921',
#  '/c/en/arbitrations/n': 90,
#  90: '/c/en/arbitrations/n',
#  '/c/en/main_ideas': 91,
#  91: '/c/en/main_ideas',
#  'at:to_set_up_the_new_microwave': 92,
#  92: 'at:to_set_up_the_new_microwave',
#  '/c/en/borrelia/n/wn/animal': 93,
#  93: '/c/en/borrelia/n/wn/animal',
#  '/c/en/rombergs/n': 94,
#  94: '/c/en/rombergs/n',
#  'at:leave_the_restaurant': 95,
#  95: 'at:leave_the_restaurant',
#  '/c/en/addend/n/wn/quantity': 96,
#  96: '/c/en/addend/n/wn/quantity',
#  '/c/en/reemergence/n': 97,
#  97: '/c/en/reemergence/n',
#  '/c/en/irrigator': 98,
#  98: '/c/en/irrigator',
#  '/c/en/light_aircraft_carrier/n': 99,
#  99: '/c/en/light_aircraft_carrier/n',
#  'at:to_win_an_oscar': 100,
#  100: 'at:to_win_an_oscar',
#  '/c/en/agrozootechnical': 101,
#  101: '/c/en/agrozootechnical',
#  '/c/en/pilliwinks': 102,
#  102: '/c/en/pilliwinks',
#  'Q892554': 103,
#  103: 'Q892554',
#  '/c/en/sea_spider/n/wn/animal': 104,
#  104: '/c/en/sea_spider/n/wn/animal',
#  '/c/en/panicles/n': 105,
#  105: '/c/en/panicles/n',
#  '/c/en/endomicroscope': 106,
#  106: '/c/en/endomicroscope',
#  '/c/en/enteroinvasive': 107,
#  107: '/c/en/enteroinvasive',
#  '/c/en/ⁿ': 108,
#  108: '/c/en/ⁿ',
#  'at:to_learn_self_control': 109,
#  109: 'at:to_learn_self_control',
#  '/c/en/trembleth': 110,
#  110: '/c/en/trembleth',
#  '/c/en/con_brio/a/wn/music': 111,
#  111: '/c/en/con_brio/a/wn/music',
#  '/c/en/high_school_freshman': 112,
#  112: '/c/en/high_school_freshman',
#  '/c/en/horned_rattlesnake': 113,
#  113: '/c/en/horned_rattlesnake',
#  '/c/en/nijinsky/n/wn/person': 114,
#  114: '/c/en/nijinsky/n/wn/person',
#  'at:to_make_person_y_angry': 115,
#  115: 'at:to_make_person_y_angry',
#  '/c/en/corncrib/n/wn/artifact': 116,
#  116: '/c/en/corncrib/n/wn/artifact',
#  '/c/en/osmunda/n': 117,
#  117: '/c/en/osmunda/n',
#  '/c/en/unpitifulness/n': 118,
#  118: '/c/en/unpitifulness/n',
#  '/c/en/vanity_mirror/n': 119,
#  119: '/c/en/vanity_mirror/n',
#  '/c/en/hebophilic/a': 120,
#  120: '/c/en/hebophilic/a',
#  'at:to_put_the_glass_down': 121,
#  121: 'at:to_put_the_glass_down',
#  '/c/en/brasero': 122,
#  122: '/c/en/brasero',
#  '/c/en/mainful': 123,
#  123: '/c/en/mainful',
#  '/c/en/booghdees/n': 124,
#  124: '/c/en/booghdees/n',
#  '/c/en/suck_out/n': 125,
#  125: '/c/en/suck_out/n',
#  '/c/en/goodnough': 126,
#  126: '/c/en/goodnough',
#  '/c/en/dummy_run': 127,
#  127: '/c/en/dummy_run',
#  '/c/en/colorimetrists/n': 128,
#  128: '/c/en/colorimetrists/n',
#  '/c/en/furthermost/a': 129,
#  129: '/c/en/furthermost/a',
#  'at:to_be_continued': 130,
#  130: 'at:to_be_continued',
#  'fn:lu:unattributed_information:purportedly': 131,
#  131: 'fn:lu:unattributed_information:purportedly',
#  '/c/en/would_be_bridegroom': 132,
#  132: '/c/en/would_be_bridegroom',
#  '/c/en/erenaghy': 133,
#  133: '/c/en/erenaghy',
#  '/c/en/16f_catheter/n': 134,
#  134: '/c/en/16f_catheter/n',
#  '/c/en/toucanlike/a': 135,
#  135: '/c/en/toucanlike/a',
#  '/c/en/agricultural_revolution/n': 136,
#  136: '/c/en/agricultural_revolution/n',
#  '/c/en/booby_trap/n/wn/artifact': 137,
#  137: '/c/en/booby_trap/n/wn/artifact',
#  '/c/en/countable_or_uncountable': 138,
#  138: '/c/en/countable_or_uncountable',
#  '/c/en/specific_fuel_consumption/n': 139,
#  139: '/c/en/specific_fuel_consumption/n',
#  '/c/en/nonauto/a': 140,
#  140: '/c/en/nonauto/a',
#  '/c/en/nonpsychic': 141,
#  141: '/c/en/nonpsychic',
#  'at:person_x_cuts_hair': 142,
#  142: 'at:person_x_cuts_hair',
#  '/c/en/antihyperinsulinemic': 143,
#  143: '/c/en/antihyperinsulinemic',
#  'at:open_noodle': 144,
#  144: 'at:open_noodle',
#  '/c/en/group_of_countries/n': 145,
#  145: '/c/en/group_of_countries/n',
#  '/c/en/elac/n': 146,
#  146: '/c/en/elac/n',
#  '/c/en/shadbird': 147,
#  147: '/c/en/shadbird',
#  '/c/en/intramyocardium/a': 148,
#  148: '/c/en/intramyocardium/a',
#  '/c/en/corcass': 149,
#  149: '/c/en/corcass',
#  'at:to_rig_the_game': 150,
#  150: 'at:to_rig_the_game',
#  '/c/en/horologe': 151,
#  151: '/c/en/horologe',
#  '/c/en/security_function/n': 152,
#  152: '/c/en/security_function/n',
#  '/c/en/adorns': 153,
#  153: '/c/en/adorns',
#  '/c/en/payoff': 154,
#  154: '/c/en/payoff',
#  '/c/en/goldennesses/n': 155,
#  155: '/c/en/goldennesses/n',
#  'at:to_quit_old_one': 156,
#  156: 'at:to_quit_old_one',
#  '/c/en/reticulophagy/n': 157,
#  157: '/c/en/reticulophagy/n',
#  '/c/en/spermatocides/n': 158,
#  158: '/c/en/spermatocides/n',
#  '/c/en/soya_milk/n/wn/food': 159,
#  159: '/c/en/soya_milk/n/wn/food',
#  '/c/en/sueable': 160,
#  160: '/c/en/sueable',
#  '/c/en/wheedle/n': 161,
#  161: '/c/en/wheedle/n',
#  '/c/en/sulfur_hexafluoride/n/wn/substance': 162,
#  162: '/c/en/sulfur_hexafluoride/n/wn/substance',
#  'fn:lu:sounds:clink': 163,
#  163: 'fn:lu:sounds:clink',
#  '/c/en/polyphonously': 164,
#  164: '/c/en/polyphonously',
#  '/c/en/armor_company/n': 165,
#  165: '/c/en/armor_company/n',
#  '/c/en/coowns/v': 166,
#  166: '/c/en/coowns/v',
#  '/c/en/stance/n/wn/cognition': 167,
#  167: '/c/en/stance/n/wn/cognition',
#  '/c/en/whiting/n/wn/food': 168,
#  168: '/c/en/whiting/n/wn/food',
#  '/c/en/gottschee': 169,
#  169: '/c/en/gottschee',
#  '/c/en/crepitations': 170,
#  170: '/c/en/crepitations',
#  'at:to_have_all_of_their_friends_around_them': 171,
#  171: 'at:to_have_all_of_their_friends_around_them',
#  '/c/en/fringe_groups/n': 172,
#  172: '/c/en/fringe_groups/n',
#  '/c/en/sleep/v/wikt/en_1': 173,
#  173: '/c/en/sleep/v/wikt/en_1',
#  '/c/en/noncatalyzed/a': 174,
#  174: '/c/en/noncatalyzed/a',
#  '/c/en/begin_to_hate': 175,
#  175: '/c/en/begin_to_hate',
#  '/c/en/enhydrites/n': 176,
#  176: '/c/en/enhydrites/n',
#  '/c/en/undersupports/n': 177,
#  177: '/c/en/undersupports/n',
#  '/c/en/mummy_brown/a/wn': 178,
#  178: '/c/en/mummy_brown/a/wn',
#  '/c/en/blood_samples/n': 179,
#  179: '/c/en/blood_samples/n',
#  'rg:en_mailing-card': 180,
#  180: 'rg:en_mailing-card',
#  '/c/en/pram_face': 181,
#  181: '/c/en/pram_face',
#  'at:person_y_is_transported_home': 182,
#  182: 'at:person_y_is_transported_home',
#  '/c/en/outdacious/a': 183,
#  183: '/c/en/outdacious/a',
#  '/c/en/halobetasol': 184,
#  184: '/c/en/halobetasol',
#  '/c/en/waterweed/n': 185,
#  185: '/c/en/waterweed/n',
#  '/c/en/violences/n': 186,
#  186: '/c/en/violences/n',
#  'at:personx_paints_my_nails_yesterday': 187,
#  187: 'at:personx_paints_my_nails_yesterday',
#  '/c/en/sharing_economies/n': 188,
#  188: '/c/en/sharing_economies/n',
#  'at:he_wants_to_enjoy_a_movie': 189,
#  189: 'at:he_wants_to_enjoy_a_movie',
#  '/c/en/karditsa/n': 190,
#  190: '/c/en/karditsa/n',
#  '/c/en/quarter_pie': 191,
#  191: '/c/en/quarter_pie',
#  '/c/en/take_baby_sitter_home': 192,
#  192: '/c/en/take_baby_sitter_home',
#  '/c/en/with_bow': 193,
#  193: '/c/en/with_bow',
#  '/c/en/humpback_salmon/n': 194,
#  194: '/c/en/humpback_salmon/n',
#  '/c/en/plish/n': 195,
#  195: '/c/en/plish/n',
#  '/c/en/muslimness/n': 196,
#  196: '/c/en/muslimness/n',
#  'fn:lu:duration_description:brief': 197,
#  197: 'fn:lu:duration_description:brief',
#  '/c/en/matter_of_time/n': 198,
#  198: '/c/en/matter_of_time/n',
#  '/c/en/active_cultures': 199,
#  199: '/c/en/active_cultures',
#  '/c/en/igarapes/n': 200,
#  200: '/c/en/igarapes/n',
#  'at:to_not_spend_their_money': 201,
#  201: 'at:to_not_spend_their_money',
#  '/c/en/findabair': 202,
#  202: '/c/en/findabair',
#  'at:wants_persony_to_wake_up_on_time': 203,
#  203: 'at:wants_persony_to_wake_up_on_time',
#  '/c/en/make_public_spectacle_of_oneself/v': 204,
#  204: '/c/en/make_public_spectacle_of_oneself/v',
#  '/c/en/belief_system': 205,
#  205: '/c/en/belief_system',
#  '/c/en/superordinate_word/n/wn/communication': 206,
#  206: '/c/en/superordinate_word/n/wn/communication',
#  '/c/en/sagebrushes/n': 207,
#  207: '/c/en/sagebrushes/n',
#  '/c/en/acantholysis/n': 208,
#  208: '/c/en/acantholysis/n',
#  '/c/en/detonator': 209,
#  209: '/c/en/detonator',
#  '/c/en/unapparent/a/wn': 210,
#  210: '/c/en/unapparent/a/wn',
#  '/c/en/bacon_shakespearean': 211,
#  211: '/c/en/bacon_shakespearean',
#  '/c/en/dermatoskeletons/n': 212,
#  212: '/c/en/dermatoskeletons/n',
#  'at:glad_to_belong': 213,
#  213: 'at:glad_to_belong',
#  'rg:en_tashmit': 214,
#  214: 'rg:en_tashmit',
#  '/c/en/acidly/r': 215,
#  215: '/c/en/acidly/r',
#  '/c/en/griller': 216,
#  216: '/c/en/griller',
#  '/c/en/gated_community/n': 217,
#  217: '/c/en/gated_community/n',
#  'at:to_stop_going_to_bars': 218,
#  218: 'at:to_stop_going_to_bars',
#  '/c/en/ivory_keys': 219,
#  219: '/c/en/ivory_keys',
#  '/c/en/inconquerable/a': 220,
#  220: '/c/en/inconquerable/a',
#  '/c/en/pulkas/n': 221,
#  221: '/c/en/pulkas/n',
#  '/c/en/ossean/n': 222,
#  222: '/c/en/ossean/n',
#  '/c/en/compunctiousness/n': 223,
#  223: '/c/en/compunctiousness/n',
#  'Q3560392': 224,
#  224: 'Q3560392',
#  '/c/en/plausibility/n': 225,
#  225: '/c/en/plausibility/n',
#  '/c/en/fall_equinox': 226,
#  226: '/c/en/fall_equinox',
#  'Q29881657': 227,
#  227: 'Q29881657',
#  'at:like_the_space_looks_bigger': 228,
#  228: 'at:like_the_space_looks_bigger',
#  '/c/en/principalls/n': 229,
#  229: '/c/en/principalls/n',
#  '/c/en/chloropropane/n': 230,
#  230: '/c/en/chloropropane/n',
#  '/c/en/ichthyic': 231,
#  231: '/c/en/ichthyic',
#  '/c/en/x_e_o_zees': 232,
#  232: '/c/en/x_e_o_zees',
#  '/c/en/antidark': 233,
#  233: '/c/en/antidark',
#  '/c/en/gisarmes/n': 234,
#  234: '/c/en/gisarmes/n',
#  '/c/en/riding_to_school': 235,
#  235: '/c/en/riding_to_school',
#  '/c/en/halal_snack_pack/n': 236,
#  236: '/c/en/halal_snack_pack/n',
#  '/c/en/sellotape': 237,
#  237: '/c/en/sellotape',
#  '/c/en/northwest_wind/n': 238,
#  238: '/c/en/northwest_wind/n',
#  '/c/en/gratis/r': 239,
#  239: '/c/en/gratis/r',
#  '/c/en/astound/v': 240,
#  240: '/c/en/astound/v',
#  '/c/en/incentive/n': 241,
#  241: '/c/en/incentive/n',
#  '/c/en/febricule/n': 242,
#  242: '/c/en/febricule/n',
#  '/c/en/acroesthesia/n': 243,
#  243: '/c/en/acroesthesia/n',
#  'at:is_sick': 244,
#  244: 'at:is_sick',
#  '/c/en/dogfish/n': 245,
#  245: '/c/en/dogfish/n',
#  '/c/en/common_caper/n/wn/plant': 246,
#  246: '/c/en/common_caper/n/wn/plant',
#  '/c/en/bursidae': 247,
#  247: '/c/en/bursidae',
#  '/c/en/check_buttons': 248,
#  248: '/c/en/check_buttons',
#  '/c/en/wooly_mammal': 249,
#  249: '/c/en/wooly_mammal',
#  'at:to_take_a_glass_out_of_the_cupboard': 250,
#  250: 'at:to_take_a_glass_out_of_the_cupboard',
#  '/c/en/parading_show_dog/n': 251,
#  251: '/c/en/parading_show_dog/n',
#  '/c/en/cosmopolitanism': 252,
#  252: '/c/en/cosmopolitanism',
#  '/c/en/amiability': 253,
#  253: '/c/en/amiability',
#  '/c/en/chinese_crested': 254,
#  254: '/c/en/chinese_crested',
#  '/c/en/old_timers_disease/n': 255,
#  255: '/c/en/old_timers_disease/n',
#  '/c/en/rivets/v': 256,
#  256: '/c/en/rivets/v',
#  '/c/en/swan_upping': 257,
#  257: '/c/en/swan_upping',
#  '/c/en/manling': 258,
#  258: '/c/en/manling',
#  '/c/en/effingham/n': 259,
#  259: '/c/en/effingham/n',
#  'at:to_buy_persony_another': 260,
#  260: 'at:to_buy_persony_another',
#  '/c/en/hydroextrusion/n': 261,
#  261: '/c/en/hydroextrusion/n',
#  '/c/en/storm_jib': 262,
#  262: '/c/en/storm_jib',
#  '/c/en/heartcut': 263,
#  263: '/c/en/heartcut',
#  'at:to_read_the_poetry': 264,
#  264: 'at:to_read_the_poetry',
#  '/c/en/bombards/n': 265,
#  265: '/c/en/bombards/n',
#  '/c/en/scalebar/n': 266,
#  266: '/c/en/scalebar/n',
#  '/c/en/reunes/v': 267,
#  267: '/c/en/reunes/v',
#  'Q29644036': 268,
#  268: 'Q29644036',
#  'at:to_brush_himself_off': 269,
#  269: 'at:to_brush_himself_off',
#  '/c/en/unpleasance/n': 270,
#  270: '/c/en/unpleasance/n',
#  '/c/en/transcriptively': 271,
#  271: '/c/en/transcriptively',
#  'at:personx_cleans_everything': 272,
#  272: 'at:personx_cleans_everything',
#  '/c/en/sorting_out/v': 273,
#  273: '/c/en/sorting_out/v',
#  '/c/en/bad_pennies/n': 274,
#  274: '/c/en/bad_pennies/n',
#  '/c/en/watershed_moment/n': 275,
#  275: '/c/en/watershed_moment/n',
#  '/c/en/velocipedist/n': 276,
#  276: '/c/en/velocipedist/n',
#  '/c/en/well_bred/a/wn': 277,
#  277: '/c/en/well_bred/a/wn',
#  '/c/en/tin_plates/v': 278,
#  278: '/c/en/tin_plates/v',
#  'Q237525': 279,
#  279: 'Q237525',
#  '/c/en/effect_of_dying': 280,
#  280: '/c/en/effect_of_dying',
#  '/c/en/go_to_gym': 281,
#  281: '/c/en/go_to_gym',
#  '/c/en/flavinate/v': 282,
#  282: '/c/en/flavinate/v',
#  "at:to_see_the_other_person's_reaction": 283,
#  283: "at:to_see_the_other_person's_reaction",
#  '/c/en/peroxydations/n': 284,
#  284: '/c/en/peroxydations/n',
#  'at:to_give_a_compliment': 285,
#  285: 'at:to_give_a_compliment',
#  '/c/en/playing_as_part_of_orchestra': 286,
#  286: '/c/en/playing_as_part_of_orchestra',
#  'at:get_strong_enough_to_get_the_cross': 287,
#  287: 'at:get_strong_enough_to_get_the_cross',
#  'fn:lu:clothing:sneaker': 288,
#  288: 'fn:lu:clothing:sneaker',
#  'Q66508134': 289,
#  289: 'Q66508134',
#  '/c/en/say_hello': 290,
#  290: '/c/en/say_hello',
#  '/c/en/microcounseling/n': 291,
#  291: '/c/en/microcounseling/n',
#  'at:to_relax_by_themselves': 292,
#  292: 'at:to_relax_by_themselves',
#  '/c/en/truckstops/n': 293,
#  293: '/c/en/truckstops/n',
#  '/c/en/lagenocanaliculate': 294,
#  294: '/c/en/lagenocanaliculate',
#  '/c/en/volcaniclastic/a': 295,
#  295: '/c/en/volcaniclastic/a',
#  'at:spends_money_on_date': 296,
#  296: 'at:spends_money_on_date',
#  '/c/en/loose_dog': 297,
#  297: '/c/en/loose_dog',
#  '/c/en/psalmes/n': 298,
#  298: '/c/en/psalmes/n',
#  'at:personx_signs_the_papers': 299,
#  299: 'at:personx_signs_the_papers',
#  '/c/en/stang_balls/n': 300,
#  300: '/c/en/stang_balls/n',
#  '/c/en/sinkos/n': 301,
#  301: '/c/en/sinkos/n',
#  '/c/en/allomonal/a': 302,
#  302: '/c/en/allomonal/a',
#  '/c/en/agalactorrhea/n': 303,
#  303: '/c/en/agalactorrhea/n',
#  '/c/en/bardolatrous': 304,
#  304: '/c/en/bardolatrous',
#  '/c/en/suspensoria/n': 305,
#  305: '/c/en/suspensoria/n',
#  '/c/en/daycare/n': 306,
#  306: '/c/en/daycare/n',
#  '/c/en/badmash/n': 307,
#  307: '/c/en/badmash/n',
#  '/c/en/dadaesque': 308,
#  308: '/c/en/dadaesque',
#  '/c/en/lithographist': 309,
#  309: '/c/en/lithographist',
#  '/c/en/supercities/n': 310,
#  310: '/c/en/supercities/n',
#  '/c/en/protege/n': 311,
#  311: '/c/en/protege/n',
#  '/c/en/withering/a': 312,
#  312: '/c/en/withering/a',
#  '/c/en/vandalised': 313,
#  313: '/c/en/vandalised',
#  'at:gets_it': 314,
#  314: 'at:gets_it',
#  '/c/en/monofluoro': 315,
#  315: '/c/en/monofluoro',
#  'at:to_have_house_with_backyard': 316,
#  316: 'at:to_have_house_with_backyard',
#  '/c/en/work_sitting_down': 317,
#  317: '/c/en/work_sitting_down',
#  'at:puts_to_sleep': 318,
#  318: 'at:puts_to_sleep',
#  '/c/en/sour_stomach/n': 319,
#  319: '/c/en/sour_stomach/n',
#  '/c/en/form_of_gun': 320,
#  320: '/c/en/form_of_gun',
#  '/c/en/nonreasoning/a': 321,
#  321: '/c/en/nonreasoning/a',
#  '/c/en/shag_hounds/n': 322,
#  322: '/c/en/shag_hounds/n',
#  "at:personx_supports_personx's_view": 323,
#  323: "at:personx_supports_personx's_view",
#  '/c/en/electrolier': 324,
#  324: '/c/en/electrolier',
#  '/c/en/theory_of_meaning': 325,
#  325: '/c/en/theory_of_meaning',
#  '/c/en/vexatious_litigation': 326,
#  326: '/c/en/vexatious_litigation',
#  'at:personx_gives_the_toy_as_a_gift': 327,
#  327: 'at:personx_gives_the_toy_as_a_gift',
#  '/c/en/boycheks/n': 328,
#  328: '/c/en/boycheks/n',
#  '/c/en/crotaphytid': 329,
#  329: '/c/en/crotaphytid',
#  '/c/en/female_him': 330,
#  330: '/c/en/female_him',
#  '/c/en/plough_into': 331,
#  331: '/c/en/plough_into',
#  'at:to_bag_up_my_order': 332,
#  332: 'at:to_bag_up_my_order',
#  '/c/en/barn_full_of_grain': 333,
#  333: '/c/en/barn_full_of_grain',
#  '/c/en/smells_bad': 334,
#  334: '/c/en/smells_bad',
#  '/c/en/arch_dam/n': 335,
#  335: '/c/en/arch_dam/n',
#  '/c/en/sf_personnel/n': 336,
#  336: '/c/en/sf_personnel/n',
#  '/c/en/fluoric_acid/n': 337,
#  337: '/c/en/fluoric_acid/n',
#  '/c/en/photocrosslinking': 338,
#  338: '/c/en/photocrosslinking',
#  '/c/en/cystamine/n': 339,
#  339: '/c/en/cystamine/n',
#  '/c/en/create_mucic': 340,
#  340: '/c/en/create_mucic',
#  '/c/en/projective_varieties/n': 341,
#  341: '/c/en/projective_varieties/n',
#  '/c/en/adrenoleukodystrophy/n': 342,
#  342: '/c/en/adrenoleukodystrophy/n',
#  '/c/en/swallow_hole/n/wn/object': 343,
#  343: '/c/en/swallow_hole/n/wn/object',
#  '/c/en/over_shoulders': 344,
#  344: '/c/en/over_shoulders',
#  '/c/en/m_s_tire': 345,
#  345: '/c/en/m_s_tire',
#  '/c/en/mere_truth': 346,
#  346: '/c/en/mere_truth',
#  '/c/en/anxiety_disorders/n': 347,
#  347: '/c/en/anxiety_disorders/n',
#  'Q66544251': 348,
#  348: 'Q66544251',
#  'at:goes_without_them': 349,
#  349: 'at:goes_without_them',
#  '/c/en/one_sided': 350,
#  350: '/c/en/one_sided',
#  '/c/en/latch/n': 351,
#  351: '/c/en/latch/n',
#  '/c/en/mountain_group': 352,
#  352: '/c/en/mountain_group',
#  'at:get_up_the_out_side': 353,
#  353: 'at:get_up_the_out_side',
#  'rg:en_jupaty': 354,
#  354: 'rg:en_jupaty',
#  'at:to_make_them_feel_better': 355,
#  355: 'at:to_make_them_feel_better',
#  '/c/en/valuations/n': 356,
#  356: '/c/en/valuations/n',
#  '/c/en/bump_into/v': 357,
#  357: '/c/en/bump_into/v',
#  '/c/en/phyllodocida': 358,
#  358: '/c/en/phyllodocida',
#  '/c/en/demilunes/n': 359,
#  359: '/c/en/demilunes/n',
#  '/c/en/cicatrix/n': 360,
#  360: '/c/en/cicatrix/n',
#  '/c/en/crybaby': 361,
#  361: '/c/en/crybaby',
#  '/c/en/controlled_flight_into_terrain': 362,
#  362: '/c/en/controlled_flight_into_terrain',
#  'Q58073267': 363,
#  363: 'Q58073267',
#  '/c/en/bohm_interpretation/n': 364,
#  364: '/c/en/bohm_interpretation/n',
#  'rg:en_lifing': 365,
#  365: 'rg:en_lifing',
#  '/c/en/unworried': 366,
#  366: '/c/en/unworried',
#  '/c/en/trowers/n': 367,
#  367: '/c/en/trowers/n',
#  '/c/en/midgetlike/a': 368,
#  368: '/c/en/midgetlike/a',
#  '/c/en/diallist/n': 369,
#  369: '/c/en/diallist/n',
#  '/c/en/binucleolate': 370,
#  370: '/c/en/binucleolate',
#  '/c/en/multitube': 371,
#  371: '/c/en/multitube',
#  '/c/en/noncommercial': 372,
#  372: '/c/en/noncommercial',
#  'at:to_make_a_right_choice': 373,
#  373: 'at:to_make_a_right_choice',
#  '/c/en/arctogaeal/a': 374,
#  374: '/c/en/arctogaeal/a',
#  'at:to_ship_out_products': 375,
#  375: 'at:to_ship_out_products',
#  '/c/en/brooks/n': 376,
#  376: '/c/en/brooks/n',
#  '/c/en/tuna_noodle_casserole': 377,
#  377: '/c/en/tuna_noodle_casserole',
#  '/c/en/science_fictiony': 378,
#  378: '/c/en/science_fictiony',
#  'at:to_ask_why_x_did_it': 379,
#  379: 'at:to_ask_why_x_did_it',
#  '/c/en/allochrony/n': 380,
#  380: '/c/en/allochrony/n',
#  '/c/en/protrusion/n/wn/act': 381,
#  381: '/c/en/protrusion/n/wn/act',
#  '/c/en/citrus_limonum': 382,
#  382: '/c/en/citrus_limonum',
#  '/c/en/intratextuality/n': 383,
#  383: '/c/en/intratextuality/n',
#  'at:for_secure_the_objects': 384,
#  384: 'at:for_secure_the_objects',
#  '/c/en/stretch/v/wn/contact': 385,
#  385: '/c/en/stretch/v/wn/contact',
#  '/c/en/countercomplainant': 386,
#  386: '/c/en/countercomplainant',
#  '/c/en/light_heartedly/r': 387,
#  387: '/c/en/light_heartedly/r',
#  'at:to_show_hospitality': 388,
#  388: 'at:to_show_hospitality',
#  '/c/en/fbw': 389,
#  389: '/c/en/fbw',
#  '/c/en/gastrosteges/n': 390,
#  390: '/c/en/gastrosteges/n',
#  'at:to_quench_his_or_her_thirst': 391,
#  391: 'at:to_quench_his_or_her_thirst',
#  '/c/en/pallium/n/wn/zoology': 392,
#  392: '/c/en/pallium/n/wn/zoology',
#  '/c/en/boondocking/v': 393,
#  393: '/c/en/boondocking/v',
#  '/c/en/entolimod/n': 394,
#  394: '/c/en/entolimod/n',
#  '/c/en/leyn/v': 395,
#  395: '/c/en/leyn/v',
#  '/c/en/advancingly/r': 396,
#  396: '/c/en/advancingly/r',
#  '/c/en/shockingest/a': 397,
#  397: '/c/en/shockingest/a',
#  'at:able_to_accomplish_task': 398,
#  398: 'at:able_to_accomplish_task',
#  'Q1231292': 399,
#  399: 'Q1231292',
#  'at:to_make_arrangements_for_safety': 400,
#  400: 'at:to_make_arrangements_for_safety',
#  '/c/en/ambassadrices': 401,
#  401: '/c/en/ambassadrices',
#  '/c/en/sleighty': 402,
#  402: '/c/en/sleighty',
#  '/c/en/deaf_language': 403,
#  403: '/c/en/deaf_language',
#  '/c/en/trudger/n/wn/person': 404,
#  404: '/c/en/trudger/n/wn/person',
#  '/c/en/changing_colors': 405,
#  405: '/c/en/changing_colors',
#  '/c/en/pertechnetates/n': 406,
#  406: '/c/en/pertechnetates/n',
#  '/c/en/backformations/n': 407,
#  407: '/c/en/backformations/n',
#  '/c/en/humberside': 408,
#  408: '/c/en/humberside',
#  '/c/en/dystrophynopathy/n': 409,
#  409: '/c/en/dystrophynopathy/n',
#  '/c/en/haakenson': 410,
#  410: '/c/en/haakenson',
#  'at:to_understand_how_persony_learns': 411,
#  411: 'at:to_understand_how_persony_learns',
#  '/c/en/hexanes/n': 412,
#  412: '/c/en/hexanes/n',
#  '/c/en/outsweetened/v': 413,
#  413: '/c/en/outsweetened/v',
#  '/c/en/sang': 414,
#  414: '/c/en/sang',
#  '/c/en/seven_and_sevens/n': 415,
#  415: '/c/en/seven_and_sevens/n',
#  '/c/en/carved_in_stone': 416,
#  416: '/c/en/carved_in_stone',
#  'at:like_an_villian': 417,
#  417: 'at:like_an_villian',
#  '/c/en/examining_people': 418,
#  418: '/c/en/examining_people',
#  '/c/en/ethery/a': 419,
#  419: '/c/en/ethery/a',
#  'at:follow_person_y': 420,
#  420: 'at:follow_person_y',
#  '/c/en/mercy_rule': 421,
#  421: '/c/en/mercy_rule',
#  '/c/en/callisters/n': 422,
#  422: '/c/en/callisters/n',
#  '/c/en/relativistic': 423,
#  423: '/c/en/relativistic',
#  '/c/en/malosma/n/wn/plant': 424,
#  424: '/c/en/malosma/n/wn/plant',
#  '/c/en/pleasure_boat': 425,
#  425: '/c/en/pleasure_boat',
#  '/c/en/roberds/n': 426,
#  426: '/c/en/roberds/n',
#  '/c/en/way_to_traverse_snow': 427,
#  427: '/c/en/way_to_traverse_snow',
#  '/c/en/st_just/n': 428,
#  428: '/c/en/st_just/n',
#  '/c/en/piecer': 429,
#  429: '/c/en/piecer',
#  '/c/en/canuckistanian': 430,
#  430: '/c/en/canuckistanian',
#  'Q7785065': 431,
#  431: 'Q7785065',
#  '/c/en/adverbial_numeral': 432,
#  432: '/c/en/adverbial_numeral',
#  '/c/en/cunnilingists/n': 433,
#  433: '/c/en/cunnilingists/n',
#  'at:learns_how_to_perform_new_job': 434,
#  434: 'at:learns_how_to_perform_new_job',
#  '/c/en/psshaw': 435,
#  435: '/c/en/psshaw',
#  '/c/en/neuropraxic/a': 436,
#  436: '/c/en/neuropraxic/a',
#  '/c/en/abbassid': 437,
#  437: '/c/en/abbassid',
#  '/c/en/unsmokeable/a': 438,
#  438: '/c/en/unsmokeable/a',
#  '/c/en/unsmilingness/n': 439,
#  439: '/c/en/unsmilingness/n',
#  '/c/en/dyclonine': 440,
#  440: '/c/en/dyclonine',
#  '/c/en/dovekeys/n': 441,
#  441: '/c/en/dovekeys/n',
#  '/c/en/carbaborane': 442,
#  442: '/c/en/carbaborane',
#  '/c/en/dauntlessness/n/wn/attribute': 443,
#  443: '/c/en/dauntlessness/n/wn/attribute',
#  '/c/en/numb': 444,
#  444: '/c/en/numb',
#  '/c/en/arch_pirate': 445,
#  445: '/c/en/arch_pirate',
#  '/c/en/leukocytic': 446,
#  446: '/c/en/leukocytic',
#  'at:to_welcome_a_close_friend': 447,
#  447: 'at:to_welcome_a_close_friend',
#  '/c/en/report': 448,
#  448: '/c/en/report',
#  'Q50401980': 449,
#  449: 'Q50401980',
#  '/c/en/assailable/a': 450,
#  450: '/c/en/assailable/a',
#  '/c/en/town/n/wn/group': 451,
#  451: '/c/en/town/n/wn/group',
#  'Q89003178': 452,
#  452: 'Q89003178',
#  '/c/en/dawted/v': 453,
#  453: '/c/en/dawted/v',
#  '/c/en/group_of_enzymes/n': 454,
#  454: '/c/en/group_of_enzymes/n',
#  '/c/en/index/n/opencyc/index_indicator_or_measure': 455,
#  455: '/c/en/index/n/opencyc/index_indicator_or_measure',
#  '/c/en/bulbiform': 456,
#  456: '/c/en/bulbiform',
#  '/c/en/upright_bassists/n': 457,
#  457: '/c/en/upright_bassists/n',
#  '/c/en/socceroos': 458,
#  458: '/c/en/socceroos',
#  '/c/en/cremators/n': 459,
#  459: '/c/en/cremators/n',
#  "/c/en/put_one's_foot_down/v": 460,
#  460: "/c/en/put_one's_foot_down/v",
#  '/c/en/vim_vigor': 461,
#  461: '/c/en/vim_vigor',
#  '/c/en/abderian/n': 462,
#  462: '/c/en/abderian/n',
#  'fn:lu:being_incarcerated:inmate': 463,
#  463: 'fn:lu:being_incarcerated:inmate',
#  '/c/en/southwestern_toad/n/wn/animal': 464,
#  464: '/c/en/southwestern_toad/n/wn/animal',
#  '/c/en/non_determinism/n': 465,
#  465: '/c/en/non_determinism/n',
#  'at:to_listen_to_them_say_what_they_think': 466,
#  466: 'at:to_listen_to_them_say_what_they_think',
#  '/c/en/gettier': 467,
#  467: '/c/en/gettier',
#  '/c/en/better_parking_space': 468,
#  468: '/c/en/better_parking_space',
#  '/c/en/change_into_exercise_clothes': 469,
#  469: '/c/en/change_into_exercise_clothes',
#  '/c/en/spring_arch': 470,
#  470: '/c/en/spring_arch',
#  '/c/en/cornous': 471,
#  471: '/c/en/cornous',
#  'at:joins_band': 472,
#  472: 'at:joins_band',
#  '/c/en/extratropical': 473,
#  473: '/c/en/extratropical',
#  'at:unpack_their_belongings': 474,
#  474: 'at:unpack_their_belongings',
#  'at:personx_reconciles_the_world_unto_himself': 475,
#  475: 'at:personx_reconciles_the_world_unto_himself',
#  'at:to_taste_good_things': 476,
#  476: 'at:to_taste_good_things',
#  '/c/en/recompelling/v': 477,
#  477: '/c/en/recompelling/v',
#  '/c/en/ableism': 478,
#  478: '/c/en/ableism',
#  '/c/en/making_fuzzy_felt_pictures': 479,
#  479: '/c/en/making_fuzzy_felt_pictures',
#  '/c/en/rock_mountains': 480,
#  480: '/c/en/rock_mountains',
#  '/c/en/bornsteins/n': 481,
#  481: '/c/en/bornsteins/n',
#  '/c/en/droskys/n': 482,
#  482: '/c/en/droskys/n',
#  'Q813233': 483,
#  483: 'Q813233',
#  '/c/en/cardosanto/n': 484,
#  484: '/c/en/cardosanto/n',
#  '/c/en/hundred_and_eightieth/a/wn': 485,
#  485: '/c/en/hundred_and_eightieth/a/wn',
#  '/c/en/dihydrophenanthrene': 486,
#  486: '/c/en/dihydrophenanthrene',
#  'at:do_things_related_to_the_change': 487,
#  487: 'at:do_things_related_to_the_change',
#  '/c/en/foreboded/v': 488,
#  488: '/c/en/foreboded/v',
#  '/c/en/arabinopyranosides/n': 489,
#  489: '/c/en/arabinopyranosides/n',
#  '/c/en/end_user/n/wn/person': 490,
#  490: '/c/en/end_user/n/wn/person',
#  '/c/en/crotalus_adamanteus/n/wn/animal': 491,
#  491: '/c/en/crotalus_adamanteus/n/wn/animal',
#  'at:to_enjoy_night_life': 492,
#  492: 'at:to_enjoy_night_life',
#  'fn:fe:conflict': 493,
#  493: 'fn:fe:conflict',
#  'rg:en_kept-up': 494,
#  494: 'rg:en_kept-up',
#  '/c/en/emically/r': 495,
#  495: '/c/en/emically/r',
#  '/c/en/disembroiling/v': 496,
#  496: '/c/en/disembroiling/v',
#  '/c/en/go_anywhere_but_florida': 497,
#  497: '/c/en/go_anywhere_but_florida',
#  '/c/en/san_diegan': 498,
#  498: '/c/en/san_diegan',
#  '/c/en/remorses/n': 499,
#  499: '/c/en/remorses/n',
#  ...}

# %%
# pick an example: 
target_entity_name = '/c/en/one_drives' # entity_name = '/c/en/goateed'
target_entity_index = entity_dict[target_entity_name]
target_entity_name,target_entity_index
# Out:
# ('/c/en/one_drives', 0)

# %%
# top5 cloest neighbors
similar_ents = annoy_index.get_nns_by_item(0, 5, include_distances=True) # get most closet 5 items
ent_dis = list(zip(similar_ents[0],similar_ents[1]))

for ent in ent_dis:
    ent_index = ent[0]
    distance = ent[1]
    ent_nam = entity_dict[ent_index]
    print(f'{ent_nam:<30} {ent_index:<10} {distance}')
# Out:
# /c/en/one_drives               0          0.0
# /c/en/scoring_homer_ball       1807674    0.2194414883852005
# /c/en/coffee_spilled           1904214    0.22471533715724945
# /c/en/computer_switched_on     530173     0.2263190597295761
# /c/en/people_love_away         1037121    0.2268425077199936
