# %% [markdown]
# ## Documentation

# %% [markdown]
# `AnnoyIndex(f, metric)`returns a new index that's read-write and stores vector of f dimensions. Metric can be "angular", "euclidean", "manhattan", "hamming", or "dot".
#
# `a.add_item(i, v)` adds item i (any nonnegative integer) with vector v. Note that it will allocate memory for max(i)+1 items.
#
# `a.build(n_trees, n_jobs=-1)` builds a forest of n_trees trees. More trees gives higher precision when querying. After calling build, no more items can be added. n_jobs specifies the number of threads used to build the trees. n_jobs=-1 uses all available CPU cores.
#
# `a.save(fn, prefault=False)` saves the index to disk and loads it (see next function). After saving, no more items can be added.
#
# `a.load(fn, prefault=False)` loads (mmaps) an index from disk. If prefault is set to True, it will pre-read the entire file into memory (using mmap with MAP_POPULATE). Default is False.
#
# `a.unload()` unloads.
#
# `a.get_nns_by_item(i, n, search_k=-1, include_distances=False)` returns the n closest items. During the query it will inspect up to search_k nodes which defaults to n_trees * n if not provided. search_k gives you a run-time tradeoff between better accuracy and speed. If you set include_distances to True, it will return a 2 element tuple with two lists in it: the second one containing all corresponding distances.
#
# `a.get_nns_by_vector(v, n, search_k=-1, include_distances=False)` same but query by vector v.
#
# `a.get_item_vector(i)` returns the vector for item i that was previously added.
#
# `a.get_distance(i, j)` returns the distance between items i and j. NOTE: this used to return the squared distance, but has been changed as of Aug 2016.
#
# `a.get_n_items()` returns the number of items in the index.
#
# `a.get_n_trees()` returns the number of trees in the index.
#
# `a.on_disk_build(fn)` prepares annoy to build the index in the specified file instead of RAM (execute before adding items, no need to save after build)
#
# `a.set_seed(seed)` will initialize the random number generator with the given seed. Only used for building up the tree, i. e. only necessary to pass this before adding the items. Will have no effect after calling a.build(n_trees) or a.load(fn).

# %% [markdown]
# ## Import library

# %%
import sys
sys.path
# Out:
# ['/Users/filipilievski/mcs/cskg/examples',
#  '/Users/filipilievski/opt/anaconda3/envs/mowgli/lib/python37.zip',
#  '/Users/filipilievski/opt/anaconda3/envs/mowgli/lib/python3.7',
#  '/Users/filipilievski/opt/anaconda3/envs/mowgli/lib/python3.7/lib-dynload',
#  '',
#  '/Users/filipilievski/opt/anaconda3/envs/mowgli/lib/python3.7/site-packages',
#  '/Users/filipilievski/opt/anaconda3/envs/mowgli/lib/python3.7/site-packages/IPython/extensions',
#  '/Users/filipilievski/.ipython']

# %%
from annoy import AnnoyIndex

# %% [markdown]
# ## Prepare Data and Index

# %%
# specify a certain entity embedding tsv file
#input_file = '/nas/home/binzhang/backup_data/complex/comp_log_dot_0.01/entities_output.tsv'
input_file='../output/embeddings/entity_embedding_100.tsv'

# %%
# build a entity name-index bi dictionary
entity_dict = {}  # {name1:0, 0:name1}

# entity dimension
dimension = 100  

# build an index that stores vector
annoy_index = AnnoyIndex(dimension, 'angular')  # angular => cos

# %%
# %%time
with open(input_file, 'r') as f:
    for index,line in enumerate(f):
        line = line.split()
        entity_name = line[0]
        entity_vec =  [ float(i) for i in line[1:]]
        entity_dict[entity_name] = index
        entity_dict[index] = entity_name
        annoy_index.add_item(index, entity_vec)
# Out:
# CPU times: user 44.3 s, sys: 797 ms, total: 45.1 s
# Wall time: 45.2 s

# %%
# builds a forest of n_trees trees. More trees gives higher precision when querying. 
annoy_index.build(100) # build(n_trees, n_jobs=-1)
# Out:
# True

# %% [markdown]
# ## Get topk entites

# %%
entity_dict
# Out:
# {'/c/en/saltyback/a': 0,
#  0: '/c/en/saltyback/a',
#  'at:to_see_what_they_are_not_showing_them': 1,
#  1: 'at:to_see_what_they_are_not_showing_them',
#  '/c/en/pot_cheese/n': 2,
#  2: '/c/en/pot_cheese/n',
#  '/c/en/set/n/wn/cognition': 3,
#  3: '/c/en/set/n/wn/cognition',
#  '/c/en/automatic_drive/n/wn/artifact': 4,
#  4: '/c/en/automatic_drive/n/wn/artifact',
#  'at:get_money_out_of_the_bank': 5,
#  5: 'at:get_money_out_of_the_bank',
#  '/c/en/emblazers/n': 6,
#  6: '/c/en/emblazers/n',
#  '/c/en/rubber_disk': 7,
#  7: '/c/en/rubber_disk',
#  '/c/en/nonshadowed': 8,
#  8: '/c/en/nonshadowed',
#  '/c/en/splayfoot/n': 9,
#  9: '/c/en/splayfoot/n',
#  '/c/en/fingercots/n': 10,
#  10: '/c/en/fingercots/n',
#  '/c/en/advertising_agency/n': 11,
#  11: '/c/en/advertising_agency/n',
#  '/c/en/arterioportography': 12,
#  12: '/c/en/arterioportography',
#  '/c/en/hebesphenomegacorona': 13,
#  13: '/c/en/hebesphenomegacorona',
#  '/c/en/lady_liberty/n': 14,
#  14: '/c/en/lady_liberty/n',
#  '/c/en/jarrah': 15,
#  15: '/c/en/jarrah',
#  '/c/en/appendicolith': 16,
#  16: '/c/en/appendicolith',
#  '/c/en/metabolas/n': 17,
#  17: '/c/en/metabolas/n',
#  '/c/en/sheep_liver_fluke': 18,
#  18: '/c/en/sheep_liver_fluke',
#  '/c/en/mayanism': 19,
#  19: '/c/en/mayanism',
#  '/c/en/status_conscious_person': 20,
#  20: '/c/en/status_conscious_person',
#  '/c/en/endangered_meat_eaters_from_north_america': 21,
#  21: '/c/en/endangered_meat_eaters_from_north_america',
#  "/c/en/miner's_elbow/n": 22,
#  22: "/c/en/miner's_elbow/n",
#  '/c/en/undistressful': 23,
#  23: '/c/en/undistressful',
#  '/c/en/past_thoughts': 24,
#  24: '/c/en/past_thoughts',
#  '/c/en/developing_skills': 25,
#  25: '/c/en/developing_skills',
#  '/c/en/isolexes/n': 26,
#  26: '/c/en/isolexes/n',
#  '/c/en/parabemata/n': 27,
#  27: '/c/en/parabemata/n',
#  '/c/en/screens/n': 28,
#  28: '/c/en/screens/n',
#  '/c/en/autoregressions/n': 29,
#  29: '/c/en/autoregressions/n',
#  '/c/en/laying_out_pattern_pieces/n': 30,
#  30: '/c/en/laying_out_pattern_pieces/n',
#  '/c/en/crushworthy': 31,
#  31: '/c/en/crushworthy',
#  '/c/en/beggarwoman': 32,
#  32: '/c/en/beggarwoman',
#  '/c/en/service_to_people_in_restaraunt': 33,
#  33: '/c/en/service_to_people_in_restaraunt',
#  '/c/en/outselling/v': 34,
#  34: '/c/en/outselling/v',
#  '/c/en/twelveth': 35,
#  35: '/c/en/twelveth',
#  '/c/en/warning_of_impending_danger': 36,
#  36: '/c/en/warning_of_impending_danger',
#  '/c/en/overcorrect': 37,
#  37: '/c/en/overcorrect',
#  '/c/en/decodings/n': 38,
#  38: '/c/en/decodings/n',
#  '/c/en/macula_lutea/n/wn/body': 39,
#  39: '/c/en/macula_lutea/n/wn/body',
#  '/c/en/emperor_seamounts': 40,
#  40: '/c/en/emperor_seamounts',
#  '/c/en/smelt_rat/v': 41,
#  41: '/c/en/smelt_rat/v',
#  '/c/en/calcographic': 42,
#  42: '/c/en/calcographic',
#  '/c/en/brookweed': 43,
#  43: '/c/en/brookweed',
#  'at:is_revered_and_thought_about_by_family_and_friends': 44,
#  44: 'at:is_revered_and_thought_about_by_family_and_friends',
#  '/c/en/cease_fire': 45,
#  45: '/c/en/cease_fire',
#  "at:to_know_personx's_thoughts": 46,
#  46: "at:to_know_personx's_thoughts",
#  '/c/en/thunderproof/a': 47,
#  47: '/c/en/thunderproof/a',
#  '/c/en/errorlessness': 48,
#  48: '/c/en/errorlessness',
#  '/c/en/earliest/a/wn': 49,
#  49: '/c/en/earliest/a/wn',
#  '/c/en/restenotic/a': 50,
#  50: '/c/en/restenotic/a',
#  '/c/en/letter_corporals/n': 51,
#  51: '/c/en/letter_corporals/n',
#  '/c/en/semitrivial': 52,
#  52: '/c/en/semitrivial',
#  '/c/en/talksome/a': 53,
#  53: '/c/en/talksome/a',
#  'Q3515434': 54,
#  54: 'Q3515434',
#  '/c/en/transsellar/a': 55,
#  55: '/c/en/transsellar/a',
#  '/c/en/askanced/v': 56,
#  56: '/c/en/askanced/v',
#  '/c/en/overstuffed': 57,
#  57: '/c/en/overstuffed',
#  'at:personx_takes_____to_the_pet_store': 58,
#  58: 'at:personx_takes_____to_the_pet_store',
#  '/c/en/dimethyl_fumarate/n': 59,
#  59: '/c/en/dimethyl_fumarate/n',
#  'at:personx_gives_the_children____': 60,
#  60: 'at:personx_gives_the_children____',
#  '/c/en/muchas/n': 61,
#  61: '/c/en/muchas/n',
#  'at:looks_in_another_direction': 62,
#  62: 'at:looks_in_another_direction',
#  '/c/en/complice': 63,
#  63: '/c/en/complice',
#  '/c/en/ring_compound': 64,
#  64: '/c/en/ring_compound',
#  '/c/en/greek_cuisine': 65,
#  65: '/c/en/greek_cuisine',
#  '/c/en/palmerworm': 66,
#  66: '/c/en/palmerworm',
#  '/c/en/hypermetropia': 67,
#  67: '/c/en/hypermetropia',
#  '/c/en/friedrich_krupp': 68,
#  68: '/c/en/friedrich_krupp',
#  '/c/en/craved/v': 69,
#  69: '/c/en/craved/v',
#  'Q4785501': 70,
#  70: 'Q4785501',
#  '/c/en/growing_things_on': 71,
#  71: '/c/en/growing_things_on',
#  '/c/en/underbrushes/n': 72,
#  72: '/c/en/underbrushes/n',
#  '/c/en/bethlemites/n': 73,
#  73: '/c/en/bethlemites/n',
#  '/c/en/miss/n/wn/communication': 74,
#  74: '/c/en/miss/n/wn/communication',
#  '/c/en/streetling': 75,
#  75: '/c/en/streetling',
#  '/c/en/traitoress/n': 76,
#  76: '/c/en/traitoress/n',
#  '/c/en/palimpsests/n': 77,
#  77: '/c/en/palimpsests/n',
#  '/c/en/sonrai': 78,
#  78: '/c/en/sonrai',
#  '/c/en/tragedically/r': 79,
#  79: '/c/en/tragedically/r',
#  '/c/en/manwhored/v': 80,
#  80: '/c/en/manwhored/v',
#  '/c/en/draughtsmen': 81,
#  81: '/c/en/draughtsmen',
#  '/c/en/pen/n/wikt/en_3': 82,
#  82: '/c/en/pen/n/wikt/en_3',
#  '/c/en/foregear': 83,
#  83: '/c/en/foregear',
#  '/c/en/all_for_one_one_for_all': 84,
#  84: '/c/en/all_for_one_one_for_all',
#  '/c/en/sulphathiazoles/n': 85,
#  85: '/c/en/sulphathiazoles/n',
#  '/c/en/physical_space_surface/n': 86,
#  86: '/c/en/physical_space_surface/n',
#  '/c/en/phlaeothripid/n': 87,
#  87: '/c/en/phlaeothripid/n',
#  '/c/en/longer_ply': 88,
#  88: '/c/en/longer_ply',
#  '/c/en/gingerich': 89,
#  89: '/c/en/gingerich',
#  '/c/en/cutting_flesh': 90,
#  90: '/c/en/cutting_flesh',
#  '/c/en/votive/n': 91,
#  91: '/c/en/votive/n',
#  '/c/en/broken_field/a/wn/football': 92,
#  92: '/c/en/broken_field/a/wn/football',
#  '/c/en/sulphanilic_acid/n': 93,
#  93: '/c/en/sulphanilic_acid/n',
#  '/c/en/teratogen/n/wn/object': 94,
#  94: '/c/en/teratogen/n/wn/object',
#  '/c/en/remonetized/v': 95,
#  95: '/c/en/remonetized/v',
#  'Q755138': 96,
#  96: 'Q755138',
#  '/c/en/off_shore_wind/n': 97,
#  97: '/c/en/off_shore_wind/n',
#  '/c/en/hairdressers/n': 98,
#  98: '/c/en/hairdressers/n',
#  '/c/en/emboliform/a': 99,
#  99: '/c/en/emboliform/a',
#  '/c/en/leg_warmers/n': 100,
#  100: '/c/en/leg_warmers/n',
#  '/c/en/zakynthiot': 101,
#  101: '/c/en/zakynthiot',
#  '/c/en/hileman': 102,
#  102: '/c/en/hileman',
#  '/c/en/nitrate_reductase': 103,
#  103: '/c/en/nitrate_reductase',
#  '/c/en/lipohemarthrosis/n': 104,
#  104: '/c/en/lipohemarthrosis/n',
#  'at:goes_inside_the_home': 105,
#  105: 'at:goes_inside_the_home',
#  'at:personx_could_get_soap_on_themselves': 106,
#  106: 'at:personx_could_get_soap_on_themselves',
#  '/c/en/smudge_attack': 107,
#  107: '/c/en/smudge_attack',
#  '/c/en/civil_engineering/n': 108,
#  108: '/c/en/civil_engineering/n',
#  'at:to_ease_difficulty': 109,
#  109: 'at:to_ease_difficulty',
#  '/c/en/roll_on/n/wn/artifact': 110,
#  110: '/c/en/roll_on/n/wn/artifact',
#  '/c/en/key_west': 111,
#  111: '/c/en/key_west',
#  '/c/en/pyros/n': 112,
#  112: '/c/en/pyros/n',
#  '/c/en/dermatophytid/n': 113,
#  113: '/c/en/dermatophytid/n',
#  '/c/en/nonshipments/n': 114,
#  114: '/c/en/nonshipments/n',
#  '/c/en/heteroaldehydes/n': 115,
#  115: '/c/en/heteroaldehydes/n',
#  '/c/en/pimpinella_anisum': 116,
#  116: '/c/en/pimpinella_anisum',
#  '/c/en/people_believe_in_things': 117,
#  117: '/c/en/people_believe_in_things',
#  '/c/en/outpreens/v': 118,
#  118: '/c/en/outpreens/v',
#  'at:to_spend_the_proceeds': 119,
#  119: 'at:to_spend_the_proceeds',
#  '/c/en/infra_order/n': 120,
#  120: '/c/en/infra_order/n',
#  '/c/en/one_who_skates_on_ice': 121,
#  121: '/c/en/one_who_skates_on_ice',
#  '/c/en/mamlambo/n': 122,
#  122: '/c/en/mamlambo/n',
#  '/c/en/grondins/n': 123,
#  123: '/c/en/grondins/n',
#  "at:to_also_look_at_person_y's_face,": 124,
#  124: "at:to_also_look_at_person_y's_face,",
#  'Q2633050': 125,
#  125: 'Q2633050',
#  '/c/en/fashion_business/n/wn/group': 126,
#  126: '/c/en/fashion_business/n/wn/group',
#  '/c/en/morality_tale': 127,
#  127: '/c/en/morality_tale',
#  '/c/en/premyelination/n': 128,
#  128: '/c/en/premyelination/n',
#  '/c/en/sub_tender': 129,
#  129: '/c/en/sub_tender',
#  '/c/en/readthrough': 130,
#  130: '/c/en/readthrough',
#  '/c/en/verbified/v': 131,
#  131: '/c/en/verbified/v',
#  '/c/en/crashing_into_tree': 132,
#  132: '/c/en/crashing_into_tree',
#  '/c/en/tetraluminium': 133,
#  133: '/c/en/tetraluminium',
#  '/c/en/spinfection': 134,
#  134: '/c/en/spinfection',
#  '/c/en/main_traffic_artery': 135,
#  135: '/c/en/main_traffic_artery',
#  '/c/en/dunkirk/n/wn/state': 136,
#  136: '/c/en/dunkirk/n/wn/state',
#  '/c/en/crouse': 137,
#  137: '/c/en/crouse',
#  '/c/en/wing_sauce/n': 138,
#  138: '/c/en/wing_sauce/n',
#  '/c/en/wear_as_little_as_possible': 139,
#  139: '/c/en/wear_as_little_as_possible',
#  'at:they_listen_to_the_lullabies': 140,
#  140: 'at:they_listen_to_the_lullabies',
#  '/c/en/process_cheese/n/wn/food': 141,
#  141: '/c/en/process_cheese/n/wn/food',
#  'fn:lu:measure_volume:busload': 142,
#  142: 'fn:lu:measure_volume:busload',
#  'Q76451517': 143,
#  143: 'Q76451517',
#  '/c/en/martyrize': 144,
#  144: '/c/en/martyrize',
#  '/c/en/zero_day_exploit': 145,
#  145: '/c/en/zero_day_exploit',
#  '/c/en/amicrovillar/a': 146,
#  146: '/c/en/amicrovillar/a',
#  'at:flinch_at_the_pain': 147,
#  147: 'at:flinch_at_the_pain',
#  '/c/en/mistrustings/n': 148,
#  148: '/c/en/mistrustings/n',
#  'at:to_write_a_review_on_a_film_review_website': 149,
#  149: 'at:to_write_a_review_on_a_film_review_website',
#  '/c/en/region/n/wn/body': 150,
#  150: '/c/en/region/n/wn/body',
#  'Q703934': 151,
#  151: 'Q703934',
#  "/c/en/have_one's_head_screwed_on_right_way/v": 152,
#  152: "/c/en/have_one's_head_screwed_on_right_way/v",
#  '/c/en/might_light_match': 153,
#  153: '/c/en/might_light_match',
#  '/c/en/minesweeper/n/wn/artifact': 154,
#  154: '/c/en/minesweeper/n/wn/artifact',
#  '/c/en/immunoreactant': 155,
#  155: '/c/en/immunoreactant',
#  '/c/en/finocchio/n/wn/food': 156,
#  156: '/c/en/finocchio/n/wn/food',
#  '/c/en/wailing_wall/n': 157,
#  157: '/c/en/wailing_wall/n',
#  '/c/en/fowlpoxviruses/n': 158,
#  158: '/c/en/fowlpoxviruses/n',
#  '/c/en/uninephrectomize': 159,
#  159: '/c/en/uninephrectomize',
#  '/c/en/work_platform': 160,
#  160: '/c/en/work_platform',
#  '/c/en/nonmetallic_gas': 161,
#  161: '/c/en/nonmetallic_gas',
#  '/c/en/haymonds/n': 162,
#  162: '/c/en/haymonds/n',
#  '/c/en/plasma_screen': 163,
#  163: '/c/en/plasma_screen',
#  '/c/en/mobisquad': 164,
#  164: '/c/en/mobisquad',
#  '/c/en/misacylated': 165,
#  165: '/c/en/misacylated',
#  '/c/en/haematein/n': 166,
#  166: '/c/en/haematein/n',
#  '/c/en/cream/a': 167,
#  167: '/c/en/cream/a',
#  '/c/en/nondubbed': 168,
#  168: '/c/en/nondubbed',
#  '/c/en/prenatal/n': 169,
#  169: '/c/en/prenatal/n',
#  '/c/en/north_northwest/n': 170,
#  170: '/c/en/north_northwest/n',
#  '/c/en/multilineage/n': 171,
#  171: '/c/en/multilineage/n',
#  'at:to_fulfill_his_dream': 172,
#  172: 'at:to_fulfill_his_dream',
#  'at:they_get_the_information_that_they_need': 173,
#  173: 'at:they_get_the_information_that_they_need',
#  '/c/en/alleviative/a': 174,
#  174: '/c/en/alleviative/a',
#  '/c/en/binoids/n': 175,
#  175: '/c/en/binoids/n',
#  '/c/en/superpattern': 176,
#  176: '/c/en/superpattern',
#  '/c/en/raceth': 177,
#  177: '/c/en/raceth',
#  '/c/en/encrypting_event/n': 178,
#  178: '/c/en/encrypting_event/n',
#  'at:to_kill_themselves': 179,
#  179: 'at:to_kill_themselves',
#  '/c/en/rejectionistic/a': 180,
#  180: '/c/en/rejectionistic/a',
#  'at:to_show_it_to_y': 181,
#  181: 'at:to_show_it_to_y',
#  'at:to_disinfect_the_knee': 182,
#  182: 'at:to_disinfect_the_knee',
#  'rg:en_cross-culturalism': 183,
#  183: 'rg:en_cross-culturalism',
#  '/c/en/manbulge/n': 184,
#  184: '/c/en/manbulge/n',
#  '/c/en/jet_setter': 185,
#  185: '/c/en/jet_setter',
#  '/c/en/brussels_sprout/n': 186,
#  186: '/c/en/brussels_sprout/n',
#  '/c/en/ornithogenic/a': 187,
#  187: '/c/en/ornithogenic/a',
#  '/c/en/get_job_away_from_home': 188,
#  188: '/c/en/get_job_away_from_home',
#  '/c/en/feedstocks/n': 189,
#  189: '/c/en/feedstocks/n',
#  '/c/en/brasier/n': 190,
#  190: '/c/en/brasier/n',
#  'at:to_be_passive_aggressive': 191,
#  191: 'at:to_be_passive_aggressive',
#  '/c/en/impaneled/v': 192,
#  192: '/c/en/impaneled/v',
#  '/c/en/bmw_m3': 193,
#  193: '/c/en/bmw_m3',
#  '/c/en/præsciences/n': 194,
#  194: '/c/en/præsciences/n',
#  'at:to_find_new_clothes': 195,
#  195: 'at:to_find_new_clothes',
#  '/c/en/daddling/v': 196,
#  196: '/c/en/daddling/v',
#  '/c/en/consulate_general': 197,
#  197: '/c/en/consulate_general',
#  'at:misses_the_throw': 198,
#  198: 'at:misses_the_throw',
#  '/c/en/subluxate': 199,
#  199: '/c/en/subluxate',
#  '/c/en/headhunters': 200,
#  200: '/c/en/headhunters',
#  '/c/en/leftie/n': 201,
#  201: '/c/en/leftie/n',
#  '/c/en/spiny_rat': 202,
#  202: '/c/en/spiny_rat',
#  '/c/en/sharpening_tool/n': 203,
#  203: '/c/en/sharpening_tool/n',
#  '/c/en/remarkers/n': 204,
#  204: '/c/en/remarkers/n',
#  'rg:en_well-reasoned': 205,
#  205: 'rg:en_well-reasoned',
#  '/c/en/functionalities/n': 206,
#  206: '/c/en/functionalities/n',
#  '/c/en/biomass_fuel': 207,
#  207: '/c/en/biomass_fuel',
#  '/c/en/elimination_tournament/n/wn/event': 208,
#  208: '/c/en/elimination_tournament/n/wn/event',
#  '/c/en/hillscape': 209,
#  209: '/c/en/hillscape',
#  '/c/en/hundredth_of': 210,
#  210: '/c/en/hundredth_of',
#  '/c/en/padas/n': 211,
#  211: '/c/en/padas/n',
#  '/c/en/millian': 212,
#  212: '/c/en/millian',
#  '/c/en/underfix/v': 213,
#  213: '/c/en/underfix/v',
#  '/c/en/afterlife/n': 214,
#  214: '/c/en/afterlife/n',
#  'at:smart_and_motivated': 215,
#  215: 'at:smart_and_motivated',
#  'fn:lu:willingness:prepared': 216,
#  216: 'fn:lu:willingness:prepared',
#  '/c/en/story_beat/n': 217,
#  217: '/c/en/story_beat/n',
#  '/c/en/micrurus/n/wn/animal': 218,
#  218: '/c/en/micrurus/n/wn/animal',
#  '/c/en/viola_d_amore': 219,
#  219: '/c/en/viola_d_amore',
#  '/c/en/quirkiest/a': 220,
#  220: '/c/en/quirkiest/a',
#  '/c/en/overpush/n': 221,
#  221: '/c/en/overpush/n',
#  '/c/en/rescuers': 222,
#  222: '/c/en/rescuers',
#  '/c/en/parallel_processing': 223,
#  223: '/c/en/parallel_processing',
#  '/c/en/instalment/n/wn/act': 224,
#  224: '/c/en/instalment/n/wn/act',
#  '/c/en/viola_clef/n/wn/communication': 225,
#  225: '/c/en/viola_clef/n/wn/communication',
#  '/c/en/june_29/n/wn/time': 226,
#  226: '/c/en/june_29/n/wn/time',
#  '/c/en/betimbered/v': 227,
#  227: '/c/en/betimbered/v',
#  '/c/en/ernst_mach': 228,
#  228: '/c/en/ernst_mach',
#  '/c/en/led_zep': 229,
#  229: '/c/en/led_zep',
#  "at:to_talk_to_y's_boyfriend": 230,
#  230: "at:to_talk_to_y's_boyfriend",
#  '/c/en/on_good_terms/a': 231,
#  231: '/c/en/on_good_terms/a',
#  'at:everyone_to_know_they_were_right': 232,
#  232: 'at:everyone_to_know_they_were_right',
#  '/c/en/plannism/n': 233,
#  233: '/c/en/plannism/n',
#  '/c/en/data_object': 234,
#  234: '/c/en/data_object',
#  '/c/en/circumlocution_office': 235,
#  235: '/c/en/circumlocution_office',
#  '/c/en/lacayos/n': 236,
#  236: '/c/en/lacayos/n',
#  '/c/en/lada/n/wp/langreo': 237,
#  237: '/c/en/lada/n/wp/langreo',
#  '/c/en/academic_degree': 238,
#  238: '/c/en/academic_degree',
#  '/c/en/premonstration': 239,
#  239: '/c/en/premonstration',
#  '/c/en/hexapolar/a': 240,
#  240: '/c/en/hexapolar/a',
#  '/c/en/pulley_block/n/wn/artifact': 241,
#  241: '/c/en/pulley_block/n/wn/artifact',
#  '/c/en/famous_building': 242,
#  242: '/c/en/famous_building',
#  '/c/en/gabber/n/wikt/en_1': 243,
#  243: '/c/en/gabber/n/wikt/en_1',
#  '/c/en/incienso/n': 244,
#  244: '/c/en/incienso/n',
#  '/c/en/redeconvolve': 245,
#  245: '/c/en/redeconvolve',
#  'at:to_get_support': 246,
#  246: 'at:to_get_support',
#  'Q17099337': 247,
#  247: 'Q17099337',
#  '/c/en/incentivise/v': 248,
#  248: '/c/en/incentivise/v',
#  '/c/en/unscorched': 249,
#  249: '/c/en/unscorched',
#  '/c/en/cut_trunk': 250,
#  250: '/c/en/cut_trunk',
#  'at:personx_has_no_idea_where_to_start': 251,
#  251: 'at:personx_has_no_idea_where_to_start',
#  '/c/en/taking_large_amounts_of_money': 252,
#  252: '/c/en/taking_large_amounts_of_money',
#  '/c/en/cross_wise/r': 253,
#  253: '/c/en/cross_wise/r',
#  'at:to_resume_his_job': 254,
#  254: 'at:to_resume_his_job',
#  '/c/en/pancrelipase': 255,
#  255: '/c/en/pancrelipase',
#  '/c/en/flash/n/wp/comics': 256,
#  256: '/c/en/flash/n/wp/comics',
#  '/c/en/laugh_machines/n': 257,
#  257: '/c/en/laugh_machines/n',
#  '/c/en/calendrical/a': 258,
#  258: '/c/en/calendrical/a',
#  '/c/en/mythicization/n': 259,
#  259: '/c/en/mythicization/n',
#  '/c/en/juxtacortical': 260,
#  260: '/c/en/juxtacortical',
#  '/c/en/no_catholics': 261,
#  261: '/c/en/no_catholics',
#  '/c/en/potter_wasp': 262,
#  262: '/c/en/potter_wasp',
#  'Q2717266': 263,
#  263: 'Q2717266',
#  '/c/en/suprablastoporal/a': 264,
#  264: '/c/en/suprablastoporal/a',
#  '/c/en/acceptive': 265,
#  265: '/c/en/acceptive',
#  '/c/en/haggai': 266,
#  266: '/c/en/haggai',
#  '/c/en/blackboard/n': 267,
#  267: '/c/en/blackboard/n',
#  '/c/en/self_pollinating/a/wn/botany': 268,
#  268: '/c/en/self_pollinating/a/wn/botany',
#  '/c/en/bipolarism': 269,
#  269: '/c/en/bipolarism',
#  'at:be_wearing_a_hat': 270,
#  270: 'at:be_wearing_a_hat',
#  '/c/en/albumenized/v': 271,
#  271: '/c/en/albumenized/v',
#  '/c/en/partially_reduced_flavin_mononucleotide/n': 272,
#  272: '/c/en/partially_reduced_flavin_mononucleotide/n',
#  'at:personx_gets_amnesia': 273,
#  273: 'at:personx_gets_amnesia',
#  '/c/en/bogeyland': 274,
#  274: '/c/en/bogeyland',
#  '/c/en/unassuaged/a': 275,
#  275: '/c/en/unassuaged/a',
#  '/c/en/superbitch': 276,
#  276: '/c/en/superbitch',
#  '/c/en/wastrel': 277,
#  277: '/c/en/wastrel',
#  '/c/en/switch/a': 278,
#  278: '/c/en/switch/a',
#  '/c/en/beggaring/v': 279,
#  279: '/c/en/beggaring/v',
#  '/c/en/ruthenians': 280,
#  280: '/c/en/ruthenians',
#  '/c/en/phytoextracting/v': 281,
#  281: '/c/en/phytoextracting/v',
#  'Q71330743': 282,
#  282: 'Q71330743',
#  '/c/en/cyprus_cedar/n': 283,
#  283: '/c/en/cyprus_cedar/n',
#  "at:personx_adapts_to_persony's_environment": 284,
#  284: "at:personx_adapts_to_persony's_environment",
#  '/c/en/liquor_licence/n/wn/communication': 285,
#  285: '/c/en/liquor_licence/n/wn/communication',
#  'at:to_buy_own_instrument': 286,
#  286: 'at:to_buy_own_instrument',
#  '/c/en/slickens/n/wikt/en_2': 287,
#  287: '/c/en/slickens/n/wikt/en_2',
#  'at:to_get_to_know_persony_better': 288,
#  288: 'at:to_get_to_know_persony_better',
#  '/c/en/couché/a': 289,
#  289: '/c/en/couché/a',
#  '/c/en/fuss/n/wn/act': 290,
#  290: '/c/en/fuss/n/wn/act',
#  '/c/en/one_hundred_percent': 291,
#  291: '/c/en/one_hundred_percent',
#  '/c/en/metabolizer': 292,
#  292: '/c/en/metabolizer',
#  '/c/en/knottiness/n/wn/attribute': 293,
#  293: '/c/en/knottiness/n/wn/attribute',
#  'at:to_take_advantage': 294,
#  294: 'at:to_take_advantage',
#  '/c/en/alderson/n': 295,
#  295: '/c/en/alderson/n',
#  'Q500467': 296,
#  296: 'Q500467',
#  '/c/en/barbs': 297,
#  297: '/c/en/barbs',
#  '/c/en/wrinkles': 298,
#  298: '/c/en/wrinkles',
#  'at:get_answered': 299,
#  299: 'at:get_answered',
#  '/c/en/supersaturate': 300,
#  300: '/c/en/supersaturate',
#  '/c/en/thirty_threes/n': 301,
#  301: '/c/en/thirty_threes/n',
#  '/c/en/foreground/v/wn/change': 302,
#  302: '/c/en/foreground/v/wn/change',
#  '/c/en/io/n/wp/programming_language': 303,
#  303: '/c/en/io/n/wp/programming_language',
#  '/c/en/preparation/n/wn/substance': 304,
#  304: '/c/en/preparation/n/wn/substance',
#  '/c/en/viminaria_denudata/n/wn/plant': 305,
#  305: '/c/en/viminaria_denudata/n/wn/plant',
#  'Q29955851': 306,
#  306: 'Q29955851',
#  '/c/en/fend_for_oneself': 307,
#  307: '/c/en/fend_for_oneself',
#  '/c/en/cleaning_dirt_from_person': 308,
#  308: '/c/en/cleaning_dirt_from_person',
#  '/c/en/dextrality/n': 309,
#  309: '/c/en/dextrality/n',
#  '/c/en/necrose/v/wn/body': 310,
#  310: '/c/en/necrose/v/wn/body',
#  'at:scared_of_the_problem': 311,
#  311: 'at:scared_of_the_problem',
#  '/c/en/open_spectrum': 312,
#  312: '/c/en/open_spectrum',
#  '/c/en/trundle_cart/n': 313,
#  313: '/c/en/trundle_cart/n',
#  '/c/en/bush_lawyer/n/wn/plant': 314,
#  314: '/c/en/bush_lawyer/n/wn/plant',
#  '/c/en/nationalized/v': 315,
#  315: '/c/en/nationalized/v',
#  'at:to_pull_out_a_hankie': 316,
#  316: 'at:to_pull_out_a_hankie',
#  '/c/en/starn/n/wikt/en_2': 317,
#  317: '/c/en/starn/n/wikt/en_2',
#  '/c/en/treecreeper/n': 318,
#  318: '/c/en/treecreeper/n',
#  '/c/en/enses/n': 319,
#  319: '/c/en/enses/n',
#  '/c/en/extractor_fan': 320,
#  320: '/c/en/extractor_fan',
#  '/c/en/subject_pronoun': 321,
#  321: '/c/en/subject_pronoun',
#  '/c/en/tunaburger/n/wn/food': 322,
#  322: '/c/en/tunaburger/n/wn/food',
#  '/c/en/mustering/v': 323,
#  323: '/c/en/mustering/v',
#  'Q19368429': 324,
#  324: 'Q19368429',
#  'Q1550400': 325,
#  325: 'Q1550400',
#  '/c/en/jaime': 326,
#  326: '/c/en/jaime',
#  '/c/en/fall_off_shelves_during_earthquake': 327,
#  327: '/c/en/fall_off_shelves_during_earthquake',
#  '/c/en/blossometh': 328,
#  328: '/c/en/blossometh',
#  '/c/en/phlebotomus/n/wn/animal': 329,
#  329: '/c/en/phlebotomus/n/wn/animal',
#  '/c/en/cnutian/a': 330,
#  330: '/c/en/cnutian/a',
#  'at:like_they_have_higher_self_esteem': 331,
#  331: 'at:like_they_have_higher_self_esteem',
#  'at:like_they_have_worked': 332,
#  332: 'at:like_they_have_worked',
#  '/c/en/sodium_alginate': 333,
#  333: '/c/en/sodium_alginate',
#  '/c/en/drug_trafficking/n': 334,
#  334: '/c/en/drug_trafficking/n',
#  'at:to_go_to_the_car_owner': 335,
#  335: 'at:to_go_to_the_car_owner',
#  'at:friends_forever': 336,
#  336: 'at:friends_forever',
#  '/c/en/unjustice/n': 337,
#  337: '/c/en/unjustice/n',
#  '/c/en/speedy_train': 338,
#  338: '/c/en/speedy_train',
#  '/c/en/random_number_generator/n': 339,
#  339: '/c/en/random_number_generator/n',
#  '/c/en/nature_animal': 340,
#  340: '/c/en/nature_animal',
#  "at:to_understand_persony's_environment": 341,
#  341: "at:to_understand_persony's_environment",
#  '/c/en/glutæi/n': 342,
#  342: '/c/en/glutæi/n',
#  '/c/en/endocurietherapy': 343,
#  343: '/c/en/endocurietherapy',
#  '/c/en/stylise': 344,
#  344: '/c/en/stylise',
#  '/c/en/placative/a/wn': 345,
#  345: '/c/en/placative/a/wn',
#  'Q1788588': 346,
#  346: 'Q1788588',
#  '/c/en/question_of_fact': 347,
#  347: '/c/en/question_of_fact',
#  '/c/en/maneabas/n': 348,
#  348: '/c/en/maneabas/n',
#  '/c/en/visual_effects': 349,
#  349: '/c/en/visual_effects',
#  'at:to_makes_friends_with_x': 350,
#  350: 'at:to_makes_friends_with_x',
#  '/c/en/nongoals/n': 351,
#  351: '/c/en/nongoals/n',
#  '/c/en/physalises/n': 352,
#  352: '/c/en/physalises/n',
#  '/c/en/deregistration': 353,
#  353: '/c/en/deregistration',
#  '/c/en/hand_fan': 354,
#  354: '/c/en/hand_fan',
#  '/c/en/whacker/n': 355,
#  355: '/c/en/whacker/n',
#  '/c/en/look_beyond/v': 356,
#  356: '/c/en/look_beyond/v',
#  'at:items_to_collect': 357,
#  357: 'at:items_to_collect',
#  '/c/en/afade/n': 358,
#  358: '/c/en/afade/n',
#  '/c/en/booer': 359,
#  359: '/c/en/booer',
#  '/c/en/heered/v': 360,
#  360: '/c/en/heered/v',
#  '/c/en/valvopathy': 361,
#  361: '/c/en/valvopathy',
#  'Q1472361': 362,
#  362: 'Q1472361',
#  '/c/en/loved_up': 363,
#  363: '/c/en/loved_up',
#  '/c/en/television_presenter': 364,
#  364: '/c/en/television_presenter',
#  '/c/en/retrieving_launched_shuttle': 365,
#  365: '/c/en/retrieving_launched_shuttle',
#  'at:everyone_to_feel_good': 366,
#  366: 'at:everyone_to_feel_good',
#  '/c/en/synoecize': 367,
#  367: '/c/en/synoecize',
#  "at:to_send_persony's_son_off": 368,
#  368: "at:to_send_persony's_son_off",
#  '/c/en/clabaugh': 369,
#  369: '/c/en/clabaugh',
#  '/c/en/interbit/a': 370,
#  370: '/c/en/interbit/a',
#  'at:to_head_out_soon': 371,
#  371: 'at:to_head_out_soon',
#  '/c/en/annis_domini/n': 372,
#  372: '/c/en/annis_domini/n',
#  'at:personx_is_brave': 373,
#  373: 'at:personx_is_brave',
#  '/c/en/dubowitz_syndrome': 374,
#  374: '/c/en/dubowitz_syndrome',
#  '/c/en/hauptman': 375,
#  375: '/c/en/hauptman',
#  '/c/en/gutturalises/v': 376,
#  376: '/c/en/gutturalises/v',
#  '/c/en/overturning': 377,
#  377: '/c/en/overturning',
#  '/c/en/iodotherapy': 378,
#  378: '/c/en/iodotherapy',
#  '/c/en/drused': 379,
#  379: '/c/en/drused',
#  '/c/en/give_friend_hug': 380,
#  380: '/c/en/give_friend_hug',
#  '/c/en/fathers_heir': 381,
#  381: '/c/en/fathers_heir',
#  '/c/en/separate_himself_from_space_shuttle': 382,
#  382: '/c/en/separate_himself_from_space_shuttle',
#  '/c/en/obtuse_angled': 383,
#  383: '/c/en/obtuse_angled',
#  '/c/en/limner': 384,
#  384: '/c/en/limner',
#  '/c/en/find_empty_washer': 385,
#  385: '/c/en/find_empty_washer',
#  '/c/en/water_animals': 386,
#  386: '/c/en/water_animals',
#  '/c/en/thought_showers/n': 387,
#  387: '/c/en/thought_showers/n',
#  '/c/en/select_travel_tour': 388,
#  388: '/c/en/select_travel_tour',
#  '/c/en/capologist': 389,
#  389: '/c/en/capologist',
#  '/c/en/doing_lot_of_paperwork': 390,
#  390: '/c/en/doing_lot_of_paperwork',
#  '/c/en/nonrenewals/n': 391,
#  391: '/c/en/nonrenewals/n',
#  '/c/en/dosshouses/n': 392,
#  392: '/c/en/dosshouses/n',
#  '/c/en/ninja_vans/n': 393,
#  393: '/c/en/ninja_vans/n',
#  '/c/en/surgical_ventricular_restoration/n': 394,
#  394: '/c/en/surgical_ventricular_restoration/n',
#  '/c/en/capsular/a/wn/anatomy': 395,
#  395: '/c/en/capsular/a/wn/anatomy',
#  '/c/en/mailing/n/wn/act': 396,
#  396: '/c/en/mailing/n/wn/act',
#  '/c/en/hypnotizer/n': 397,
#  397: '/c/en/hypnotizer/n',
#  '/c/en/galactosides/n': 398,
#  398: '/c/en/galactosides/n',
#  '/c/en/hydroxonium': 399,
#  399: '/c/en/hydroxonium',
#  '/c/en/attracticide': 400,
#  400: '/c/en/attracticide',
#  '/c/en/semitractor/n': 401,
#  401: '/c/en/semitractor/n',
#  'at:receives_new_skills_from_personx': 402,
#  402: 'at:receives_new_skills_from_personx',
#  'at:to_keep_them_under_control': 403,
#  403: 'at:to_keep_them_under_control',
#  '/c/en/orchestrate': 404,
#  404: '/c/en/orchestrate',
#  '/c/en/multiparas/n': 405,
#  405: '/c/en/multiparas/n',
#  '/c/en/unwariness/n/wn/attribute': 406,
#  406: '/c/en/unwariness/n/wn/attribute',
#  '/c/en/fampools/n': 407,
#  407: '/c/en/fampools/n',
#  'at:personx_sweats_from_nerves': 408,
#  408: 'at:personx_sweats_from_nerves',
#  '/c/en/soundpersons/n': 409,
#  409: '/c/en/soundpersons/n',
#  '/c/en/hempvine/n': 410,
#  410: '/c/en/hempvine/n',
#  '/c/en/pollyannas/n': 411,
#  411: '/c/en/pollyannas/n',
#  '/c/en/difficilitated/v': 412,
#  412: '/c/en/difficilitated/v',
#  '/c/en/vesuviated/v': 413,
#  413: '/c/en/vesuviated/v',
#  '/c/en/burn_candle_at_both_ends': 414,
#  414: '/c/en/burn_candle_at_both_ends',
#  'at:to_have_an_interest_in_something': 415,
#  415: 'at:to_have_an_interest_in_something',
#  'Q89003669': 416,
#  416: 'Q89003669',
#  '/c/en/blood_pressure': 417,
#  417: '/c/en/blood_pressure',
#  '/c/en/endoevaporite/n': 418,
#  418: '/c/en/endoevaporite/n',
#  '/c/en/being_in_bad_situation': 419,
#  419: '/c/en/being_in_bad_situation',
#  '/c/en/rubygate/n': 420,
#  420: '/c/en/rubygate/n',
#  '/c/en/huff/v/wn/body': 421,
#  421: '/c/en/huff/v/wn/body',
#  '/c/en/muci': 422,
#  422: '/c/en/muci',
#  '/c/en/shoemake': 423,
#  423: '/c/en/shoemake',
#  'at:better_understands_the_situation': 424,
#  424: 'at:better_understands_the_situation',
#  '/c/en/unapprovable': 425,
#  425: '/c/en/unapprovable',
#  '/c/en/heptahelical': 426,
#  426: '/c/en/heptahelical',
#  '/c/en/legal_code': 427,
#  427: '/c/en/legal_code',
#  '/c/en/metaleptic': 428,
#  428: '/c/en/metaleptic',
#  'at:to_of_lost_the_dog': 429,
#  429: 'at:to_of_lost_the_dog',
#  '/c/en/filling/n/wn/act': 430,
#  430: '/c/en/filling/n/wn/act',
#  '/c/en/orsellates/n': 431,
#  431: '/c/en/orsellates/n',
#  '/c/en/bear_cat/n': 432,
#  432: '/c/en/bear_cat/n',
#  '/c/en/clown_beetle': 433,
#  433: '/c/en/clown_beetle',
#  '/c/en/pyrotherapy/n': 434,
#  434: '/c/en/pyrotherapy/n',
#  '/c/en/pres_brake_pedal': 435,
#  435: '/c/en/pres_brake_pedal',
#  '/c/en/expansion_turbines/n': 436,
#  436: '/c/en/expansion_turbines/n',
#  '/c/en/odontalgic': 437,
#  437: '/c/en/odontalgic',
#  'at:is_glad_personx_learned': 438,
#  438: 'at:is_glad_personx_learned',
#  'Q28599311': 439,
#  439: 'Q28599311',
#  '/c/en/undeviating': 440,
#  440: '/c/en/undeviating',
#  '/c/en/scarlet_tanager/n/wn/animal': 441,
#  441: '/c/en/scarlet_tanager/n/wn/animal',
#  '/c/en/fire_teaser/n': 442,
#  442: '/c/en/fire_teaser/n',
#  '/c/en/nothocestrum': 443,
#  443: '/c/en/nothocestrum',
#  '/c/en/furanochromone': 444,
#  444: '/c/en/furanochromone',
#  "at:personx_asks_personx's_neighbor": 445,
#  445: "at:personx_asks_personx's_neighbor",
#  '/c/en/silvery_green/a/wn': 446,
#  446: '/c/en/silvery_green/a/wn',
#  '/c/en/re_provisions/v': 447,
#  447: '/c/en/re_provisions/v',
#  '/c/en/order_lobata/n/wn/animal': 448,
#  448: '/c/en/order_lobata/n/wn/animal',
#  'at:to_use_the_medicine_to_get_better': 449,
#  449: 'at:to_use_the_medicine_to_get_better',
#  'at:to_communicate_findings_to_otheres': 450,
#  450: 'at:to_communicate_findings_to_otheres',
#  '/c/en/amusical': 451,
#  451: '/c/en/amusical',
#  '/c/en/scrine': 452,
#  452: '/c/en/scrine',
#  '/c/en/posterior_descending_circumflex_artery/n': 453,
#  453: '/c/en/posterior_descending_circumflex_artery/n',
#  '/c/en/lawyer_readable/a': 454,
#  454: '/c/en/lawyer_readable/a',
#  '/c/en/muslimism': 455,
#  455: '/c/en/muslimism',
#  'fn:fe:institution': 456,
#  456: 'fn:fe:institution',
#  '/c/en/regimen/n/wn/medicine': 457,
#  457: '/c/en/regimen/n/wn/medicine',
#  '/c/en/ras/n/wn/body': 458,
#  458: '/c/en/ras/n/wn/body',
#  '/c/en/gooseberrying/n': 459,
#  459: '/c/en/gooseberrying/n',
#  '/c/en/proangiogenic/a': 460,
#  460: '/c/en/proangiogenic/a',
#  '/c/en/common_woodpigeons/n': 461,
#  461: '/c/en/common_woodpigeons/n',
#  'at:person_x_to_stop_touching_them': 462,
#  462: 'at:person_x_to_stop_touching_them',
#  'Q833899': 463,
#  463: 'Q833899',
#  '/c/en/stylographical/a': 464,
#  464: '/c/en/stylographical/a',
#  '/c/en/raved/v': 465,
#  465: '/c/en/raved/v',
#  '/c/en/practicalism': 466,
#  466: '/c/en/practicalism',
#  '/c/en/palatalise': 467,
#  467: '/c/en/palatalise',
#  '/c/en/jod': 468,
#  468: '/c/en/jod',
#  '/c/en/defined_in_many_ways': 469,
#  469: '/c/en/defined_in_many_ways',
#  '/c/en/intangible_object_relating_predicate/n': 470,
#  470: '/c/en/intangible_object_relating_predicate/n',
#  '/c/en/chupot/n': 471,
#  471: '/c/en/chupot/n',
#  '/c/en/water_ski/v': 472,
#  472: '/c/en/water_ski/v',
#  '/c/en/ramus/n': 473,
#  473: '/c/en/ramus/n',
#  '/c/en/getting_grade_in_class': 474,
#  474: '/c/en/getting_grade_in_class',
#  '/c/en/irreformable': 475,
#  475: '/c/en/irreformable',
#  "at:personx_goes_bowling_with_persony's_friends": 476,
#  476: "at:personx_goes_bowling_with_persony's_friends",
#  'Q1828742': 477,
#  477: 'Q1828742',
#  '/c/en/xeroderma_pigmentosum': 478,
#  478: '/c/en/xeroderma_pigmentosum',
#  "at:personx_gets_personx's_first_job": 479,
#  479: "at:personx_gets_personx's_first_job",
#  'at:to_see_the_reaction': 480,
#  480: 'at:to_see_the_reaction',
#  '/c/en/cubosome/n': 481,
#  481: '/c/en/cubosome/n',
#  '/c/en/pristigasterids/n': 482,
#  482: '/c/en/pristigasterids/n',
#  'at:person_y_eats_the_food': 483,
#  483: 'at:person_y_eats_the_food',
#  '/c/en/mullid/n': 484,
#  484: '/c/en/mullid/n',
#  '/c/en/mower/n': 485,
#  485: '/c/en/mower/n',
#  '/c/en/gardy_loo': 486,
#  486: '/c/en/gardy_loo',
#  'at:to_burn_the_flag': 487,
#  487: 'at:to_burn_the_flag',
#  'at:have_fun_doing_it': 488,
#  488: 'at:have_fun_doing_it',
#  '/c/en/crazy_ants/n': 489,
#  489: '/c/en/crazy_ants/n',
#  '/c/en/nanoamp': 490,
#  490: '/c/en/nanoamp',
#  '/c/en/etoperidone/n': 491,
#  491: '/c/en/etoperidone/n',
#  'at:get_meeting_notes': 492,
#  492: 'at:get_meeting_notes',
#  '/c/en/cojobas/n': 493,
#  493: '/c/en/cojobas/n',
#  '/c/en/earnings/n/opencyc/receiving_payment': 494,
#  494: '/c/en/earnings/n/opencyc/receiving_payment',
#  '/c/en/kitemark': 495,
#  495: '/c/en/kitemark',
#  'at:gets_sore_muscles_from_force_of_pushing_other_person': 496,
#  496: 'at:gets_sore_muscles_from_force_of_pushing_other_person',
#  '/c/en/hedylid/n': 497,
#  497: '/c/en/hedylid/n',
#  '/c/en/bandwidth/n': 498,
#  498: '/c/en/bandwidth/n',
#  'fn:lu:proportional_quantity:or_so': 499,
#  499: 'fn:lu:proportional_quantity:or_so',
#  ...}

# %%
# pick an example: 
target_entity_name = '/c/en/caffeine' # entity_name = '/c/en/goateed'
target_entity_index = entity_dict[target_entity_name]
target_entity_name,target_entity_index
# Out:
# ('/c/en/caffeine', 1979706)

# %%
# top5 cloest neighbors
similar_ents = annoy_index.get_nns_by_item(1979706, 5, include_distances=True) # get most closet 5 items
ent_dis = list(zip(similar_ents[0],similar_ents[1]))

for ent in ent_dis:
    ent_index = ent[0]
    distance = ent[1]
    ent_nam = entity_dict[ent_index]
    print(f'{ent_nam:<30} {ent_index:<10} {distance}')
    print()
# Out:
# /c/en/caffeine                 1979706    0.0
#
# /c/en/keep_awake               219997     0.6564935445785522
#
# /c/en/alkaloid_drug_with_stimulant_action 1343731    0.7606598138809204
#
# /c/en/overcaffeinated/a        182020     0.8577694296836853
#
# /c/en/coke/n                   2135040    1.089383840560913
