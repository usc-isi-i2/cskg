# %% [markdown]
# # Playing with CSKG grounding

# %% [markdown]
# # Setup for grounding
#
# ```
# conda create -n mowgli python=3.6
# conda activate mowgli
#
# git clone https://github.com/ucinlp/mowgli-uci
#
# mv mowgli-uci grounding
#
# cd grounding
#
# pip install -r requirements.txt
# conda install --yes faiss-cpu -c pytorch -n mowgli
# python -m spacy download en_core_web_lg
#
# cd ..
# ```

# %%
# IMPORTS
import pygraphviz as pgv
from IPython.display import Image

# %% [markdown]
# ## I. Parsing questions and answers

# %%
import sys
sys.path.append('..')
from groundcn.graphify import graphify

# %%
def draw(G):
    return Image(G.draw(format='png', prog='dot'))

# %%
sentences=[
    'Max looked for the onions so that he could make a stew.',
#    'To get the bathroom counters dry after washing your face, take a small hand lotion and wipe away the extra water around the sink.',
#    'To get the bathroom counters dry after washing your face, take a small hand towel and wipe away the extra water around the sink.'
]

# %%
parse_trees=graphify.graphify_dataset(sentences)
# Out:
# /Users/filipilievski/opt/anaconda3/envs/mowgli/lib/python3.7/site-packages/torch/nn/modules/rnn.py:61: UserWarning: dropout option adds dropout after all but last recurrent layer, so non-zero dropout expects num_layers greater than 1, but got dropout=0.2 and num_layers=1
#   "num_layers={}".format(dropout, num_layers))
# /Users/filipilievski/opt/anaconda3/envs/mowgli/lib/python3.7/site-packages/allennlp/data/token_indexers/token_characters_indexer.py:56: UserWarning: You are using the default value (0) of `min_padding_length`, which can cause some subtle bugs (more info see https://github.com/allenai/allennlp/issues/1954). Strongly recommend to set a value, usually the maximum size of the convolutional layer size when using CnnEncoder.
#   UserWarning)
#   0%|          | 0/1 [00:00<?, ?it/s]WARNING:allennlp.models.model:Encountered the antecedent_indices key in the model's return dictionary which couldn't be split by the batch size. Key will be ignored.
# 100%|██████████| 1/1 [00:00<00:00,  4.78it/s]

# %%
parse_trees
# Out:
# [{'sentence': 'Max looked for the onions so that he could make a stew.',
#   'tokenized_sentence': ['Max',
#    'looked',
#    'for',
#    'the',
#    'onions',
#    'so',
#    'that',
#    'he',
#    'could',
#    'make',
#    'a',
#    'stew',
#    '.'],
#   'nodes': {'b8b44c42212269fa82b8a800e4d05b3b': {'phrase': ['looked'],
#     'start_idx': 1,
#     'end_idx': 1,
#     'entity_type': [None]},
#    'd7f12a857dcf22242159a4ac9c75e4a7': {'phrase': ['Max'],
#     'start_idx': 0,
#     'end_idx': 0,
#     'entity_type': ['PERSON']},
#    '9d49eb0165f37563ceec0f4aace44eeb': {'phrase': ['for', 'the', 'onions'],
#     'start_idx': 2,
#     'end_idx': 4,
#     'entity_type': [None, None, None]},
#    '38e60e63114e00d392d337e9a9c16898': {'phrase': ['so',
#      'that',
#      'he',
#      'could',
#      'make',
#      'a',
#      'stew'],
#     'start_idx': 5,
#     'end_idx': 11,
#     'entity_type': [None, None, None, None, None, None, None]},
#    '5ae027510ceb98789ca570c5ba998f3c': {'phrase': ['make'],
#     'start_idx': 9,
#     'end_idx': 9,
#     'entity_type': [None]},
#    'd912aad50048df6360128cc250b052ad': {'phrase': ['he'],
#     'start_idx': 7,
#     'end_idx': 7,
#     'entity_type': [None]},
#    'b0885c0a23322aee012ea110470da1de': {'phrase': ['could'],
#     'start_idx': 8,
#     'end_idx': 8,
#     'entity_type': [None]},
#    '79b9dd007e266a328840fc9ae080deb7': {'phrase': ['a', 'stew'],
#     'start_idx': 10,
#     'end_idx': 11,
#     'entity_type': [None, None]}},
#   'edges': {'b34612221794b97a02871814d382fa9a': {'head_node_id': 'b8b44c42212269fa82b8a800e4d05b3b',
#     'tail_node_id': 'd7f12a857dcf22242159a4ac9c75e4a7',
#     'edge_name': 'ARG0',
#     'edge_source': 'srl'},
#    'd99d51111baf9eb830b1760596635287': {'head_node_id': 'b8b44c42212269fa82b8a800e4d05b3b',
#     'tail_node_id': '9d49eb0165f37563ceec0f4aace44eeb',
#     'edge_name': 'ARG1',
#     'edge_source': 'srl'},
#    'ede386e7a285f921dfcf844486cd402b': {'head_node_id': 'b8b44c42212269fa82b8a800e4d05b3b',
#     'tail_node_id': '38e60e63114e00d392d337e9a9c16898',
#     'edge_name': 'ARGM-PRP',
#     'edge_source': 'srl'},
#    '7d03adf89fd8836ae89509e71e402572': {'head_node_id': '5ae027510ceb98789ca570c5ba998f3c',
#     'tail_node_id': 'd912aad50048df6360128cc250b052ad',
#     'edge_name': 'ARG0',
#     'edge_source': 'srl'},
#    '9f4aadc7dd212241f93cbe5f71b4b1a2': {'head_node_id': '5ae027510ceb98789ca570c5ba998f3c',
#     'tail_node_id': 'b0885c0a23322aee012ea110470da1de',
#     'edge_name': 'ARGM-MOD',
#     'edge_source': 'srl'},
#    'a11eb0f599fee11c47952fc1342454bb': {'head_node_id': '5ae027510ceb98789ca570c5ba998f3c',
#     'tail_node_id': '79b9dd007e266a328840fc9ae080deb7',
#     'edge_name': 'ARG1',
#     'edge_source': 'srl'},
#    'aa7d0146576383c87c1cd00b18383059': {'head_node_id': '38e60e63114e00d392d337e9a9c16898',
#     'tail_node_id': '5ae027510ceb98789ca570c5ba998f3c',
#     'edge_name': 'sub',
#     'edge_source': 'srl'},
#    '632ba60b14643479e34f05678ac1d258': {'head_node_id': '38e60e63114e00d392d337e9a9c16898',
#     'tail_node_id': 'd912aad50048df6360128cc250b052ad',
#     'edge_name': 'sub',
#     'edge_source': 'srl'},
#    '4442285927cdfa7c8239ee4ea23fe1f3': {'head_node_id': '38e60e63114e00d392d337e9a9c16898',
#     'tail_node_id': 'b0885c0a23322aee012ea110470da1de',
#     'edge_name': 'sub',
#     'edge_source': 'srl'},
#    'c636ac71fe4a1ba247bc089b63d5b85e': {'head_node_id': '38e60e63114e00d392d337e9a9c16898',
#     'tail_node_id': '79b9dd007e266a328840fc9ae080deb7',
#     'edge_name': 'sub',
#     'edge_source': 'srl'},
#    '048ed92954a324a5badab5936d25286f': {'head_node_id': 'd7f12a857dcf22242159a4ac9c75e4a7',
#     'tail_node_id': 'd912aad50048df6360128cc250b052ad',
#     'edge_name': 'coref',
#     'edge_source': 'coref'}}}]

# %% [markdown]
# ### Nicer visualization

# %%
rels=[]
for sent_data in parse_trees:
    #print('Sentence:', sent_data['sentence'])
    #print('Tokenized sentence', sent_data['tokenized_sentence'])

    G=pgv.AGraph(strict=False, directed=True)
    
    nodes={}
    for n_id, n_data in sent_data['nodes'].items():
        nodes[n_id]=' '.join(n_data['phrase'])
    
    for e_id, e_data in sent_data['edges'].items():
        n1=nodes[e_data['head_node_id']]
        n2=nodes[e_data['tail_node_id']]
        rel=e_data['edge_name']
        edge=(e_data['head_node_id'], rel, e_data['tail_node_id'])
        rels.append(edge)
        
        G.add_edge(n1, n2, label=rel)

# %%
draw(G)

# %% [markdown]
# ## II. Grounding questions and questions to ConceptNet

# %%
from groundcn.graphify import link

# %%
numberbatch_file='../groundcn/numberbatch-en-19.08.txt'

# %%
linked_data=link.link(parse_trees, embedding_file=numberbatch_file)
# Out:
# 100%|██████████| 516782/516782 [00:36<00:00, 14254.83it/s]

# %%
rels
# Out:
# [('b8b44c42212269fa82b8a800e4d05b3b',
#   'ARG0',
#   'd7f12a857dcf22242159a4ac9c75e4a7'),
#  ('b8b44c42212269fa82b8a800e4d05b3b',
#   'ARG1',
#   '9d49eb0165f37563ceec0f4aace44eeb'),
#  ('b8b44c42212269fa82b8a800e4d05b3b',
#   'ARGM-PRP',
#   '38e60e63114e00d392d337e9a9c16898'),
#  ('5ae027510ceb98789ca570c5ba998f3c',
#   'ARG0',
#   'd912aad50048df6360128cc250b052ad'),
#  ('5ae027510ceb98789ca570c5ba998f3c',
#   'ARGM-MOD',
#   'b0885c0a23322aee012ea110470da1de'),
#  ('5ae027510ceb98789ca570c5ba998f3c',
#   'ARG1',
#   '79b9dd007e266a328840fc9ae080deb7'),
#  ('38e60e63114e00d392d337e9a9c16898',
#   'sub',
#   '5ae027510ceb98789ca570c5ba998f3c'),
#  ('38e60e63114e00d392d337e9a9c16898',
#   'sub',
#   'd912aad50048df6360128cc250b052ad'),
#  ('38e60e63114e00d392d337e9a9c16898',
#   'sub',
#   'b0885c0a23322aee012ea110470da1de'),
#  ('38e60e63114e00d392d337e9a9c16898',
#   'sub',
#   '79b9dd007e266a328840fc9ae080deb7'),
#  ('d7f12a857dcf22242159a4ac9c75e4a7',
#   'coref',
#   'd912aad50048df6360128cc250b052ad')]

# %%
links={}
for sent_data in linked_data:
    print('Sentence:', sent_data['sentence'])
    linkedG=pgv.AGraph(strict=False, directed=True)
    for n_id, n_data in sent_data['nodes'].items():
        print('Node phrase:', n_data['phrase'])
        for c in reversed(n_data['candidates']):
            print(c)
        print()
        
        links[n_id]=list(reversed(n_data['candidates']))[0]['uri']

    for edge in rels:
        linkedG.add_edge(links[edge[0]], links[edge[2]], label=edge[1])
    print()
# Out:
# Sentence: Max looked for the onions so that he could make a stew.
# Node phrase: ['looked']
# {'uri': '/c/en/give_glad_eye', 'score': 0.2498762607574463}
# {'uri': '/c/en/uplook', 'score': 0.2498762607574463}
# {'uri': '/c/en/look', 'score': 0.24307048320770264}
# {'uri': '/c/en/lookt', 'score': 0.1385062336921692}
# {'uri': '/c/en/looked', 'score': -1.0967254638671875e-05}
#
# Node phrase: ['Max']
# {'uri': '/c/en/maxy', 'score': 0.2219405174255371}
# {'uri': '/c/en/maxie', 'score': 0.2098349928855896}
# {'uri': '/c/en/maxine', 'score': 0.19799458980560303}
# {'uri': '/c/en/maximus', 'score': 0.1656038761138916}
# {'uri': '/c/en/max', 'score': 2.1219253540039062e-05}
#
# Node phrase: ['for', 'the', 'onions']
# {'uri': '/c/en/vidalia_onion', 'score': 0.11641442775726318}
# {'uri': '/c/en/onion', 'score': 0.10344946384429932}
# {'uri': '/c/en/ingredient_in_salsa', 'score': 0.09622251987457275}
# {'uri': '/c/en/onions', 'score': 8.165836334228516e-05}
# {'uri': '/c/en/for', 'score': 2.2649765014648438e-06}
#
# Node phrase: ['so', 'that', 'he', 'could', 'make', 'a', 'stew']
# {'uri': '/c/en/make', 'score': 3.3736228942871094e-05}
# {'uri': '/c/en/so_that', 'score': 2.2113323211669922e-05}
# {'uri': '/c/en/he', 'score': 9.179115295410156e-06}
# {'uri': '/c/en/could', 'score': -2.9921531677246094e-05}
# {'uri': '/c/en/stew', 'score': -8.463859558105469e-05}
#
# Node phrase: ['make']
# {'uri': '/c/en/foremake', 'score': 0.18033039569854736}
# {'uri': '/c/en/maketh', 'score': 0.1189420223236084}
# {'uri': '/c/en/makest', 'score': 0.07135224342346191}
# {'uri': '/c/en/film_make', 'score': 0.005058348178863525}
# {'uri': '/c/en/make', 'score': 3.3736228942871094e-05}
#
# Node phrase: ['he']
# {'uri': "/c/en/he's", 'score': 0.1669536828994751}
# {'uri': '/c/en/she', 'score': 0.15240478515625}
# {'uri': '/c/en/he_or_she', 'score': 0.11238044500350952}
# {'uri': '/c/en/s_he', 'score': 0.09848588705062866}
# {'uri': '/c/en/he', 'score': 9.179115295410156e-06}
#
# Node phrase: ['could']
# {'uri': '/c/en/would', 'score': 0.12528467178344727}
# {'uri': '/c/en/couldn’t', 'score': 0.07447981834411621}
# {'uri': '/c/en/couldst', 'score': 0.06240642070770264}
# {'uri': "/c/en/couldn't", 'score': 0.05818939208984375}
# {'uri': '/c/en/could', 'score': -2.9921531677246094e-05}
#
# Node phrase: ['a', 'stew']
# {'uri': '/c/en/stews', 'score': 0.0810580849647522}
# {'uri': '/c/en/stewy', 'score': 0.05264413356781006}
# {'uri': '/c/en/lobster_stew', 'score': 0.010990381240844727}
# {'uri': '/c/en/oyster_stew', 'score': 0.008328914642333984}
# {'uri': '/c/en/stew', 'score': -8.463859558105469e-05}

# %%
draw(linkedG)

# %% [markdown]
# ## III. Grounding to CSKG

# %%
from groundcskg.graphify import link

# %%
ft_emb_file='../groundcskg/ft.txt'
graph_emb_file='../output/embeddings/graph_embedding.tsv'
bert_file='../output/embeddings/bert_nli_large_w2v_format.txt'

# %%
import importlib
importlib.reload(link)
# Out:
# <module 'groundcskg.graphify.link' from '../groundcskg/graphify/link.py'>

# %%
linked_data=link.link(parse_trees, embedding_file=bert_file)
# Out:
# ['looked']
# ['Max']
# ['for', 'the', 'onions']
# ['so', 'that', 'he', 'could', 'make', 'a', 'stew']
# ['make']
# ['he']
# ['could']
# ['a', 'stew']

# %%
links={}
for sent_data in linked_data:
    print('Sentence:', sent_data['sentence'])
    linkedG=pgv.AGraph(strict=False, directed=True)
    for n_id, n_data in sent_data['nodes'].items():
        print('Node phrase:', n_data['phrase'])
        for c in reversed(n_data['candidates']):
            print(c)
        print()
        
        links[n_id]=list(reversed(n_data['candidates']))[0]['uri']

    for edge in rels:
        linkedG.add_edge(links[edge[0]], links[edge[2]], label=edge[1])
    print()
# Out:
# Sentence: Max looked for the onions so that he could make a stew.
# Node phrase: ['looked']
# {'uri': '/c/en/looks/n', 'score': 0.04993098974227905}
# {'uri': '/c/en/looks/v', 'score': 0.04993098974227905}
# {'uri': 'at:looked_at', 'score': 0.04919767379760742}
# {'uri': '/c/en/looked/v', 'score': 0.023923277854919434}
# {'uri': '/c/en/looked', 'score': 0.023923277854919434}
#
# Node phrase: ['Max']
# {'uri': '/c/en/reached_max', 'score': 0.06083834171295166}
# {'uri': '/c/en/max/n/wn/artifact', 'score': 0.031417250633239746}
# {'uri': '/c/en/max/a', 'score': 0.031417250633239746}
# {'uri': '/c/en/max/v', 'score': 0.031417250633239746}
# {'uri': '/c/en/max/n', 'score': 0.031417250633239746}
#
# Node phrase: ['for', 'the', 'onions']
# {'uri': '/c/en/cut_onions', 'score': 0.08701491355895996}
# {'uri': '/c/en/multiplier_onions/n', 'score': 0.08609789609909058}
# {'uri': '/c/en/storing_onions', 'score': 0.0823129415512085}
# {'uri': "/c/en/know_one's_onions", 'score': 0.07984781265258789}
# {'uri': "/c/en/know_one's_onions/v", 'score': 0.07984781265258789}
#
# Node phrase: ['so', 'that', 'he', 'could', 'make', 'a', 'stew']
# {'uri': '/c/en/make_stew', 'score': 0.14661955833435059}
# {'uri': 'at:to_eat_the_stew', 'score': 0.13241583108901978}
# {'uri': 'at:help_with_stew', 'score': 0.13109099864959717}
# {'uri': '/c/en/add_ingredients_to_stew', 'score': 0.12441670894622803}
# {'uri': 'at:ingredients_for_the_stew', 'score': 0.11924505233764648}
#
# Node phrase: ['make']
# {'uri': 'fn:lu:type:make', 'score': 0.03853338956832886}
# {'uri': '/c/en/make/v/wn/possession', 'score': 0.03853338956832886}
# {'uri': '/c/en/make/v/wn/contact', 'score': 0.03853338956832886}
# {'uri': 'fn:lu:earnings_and_losses:make', 'score': 0.03853338956832886}
# {'uri': 'fn:lu:creating:make', 'score': 0.03853338956832886}
#
# Node phrase: ['he']
# {'uri': '/c/en/he/n/wn/substance', 'score': 0.02900254726409912}
# {'uri': '/c/en/he/n/wikt/en_1', 'score': 0.02900254726409912}
# {'uri': '/c/en/he/n', 'score': 0.02900254726409912}
# {'uri': '/c/en/he/n/wp/kana', 'score': 0.02900254726409912}
# {'uri': '/c/en/he/n/wikt/en_2', 'score': 0.02900254726409912}
#
# Node phrase: ['could']
# {'uri': '/c/en/coulde/v', 'score': 0.059609174728393555}
# {'uri': '/c/en/could/n', 'score': 0.03609025478363037}
# {'uri': '/c/en/could', 'score': 0.03609025478363037}
# {'uri': 'fn:lu:possibility:could', 'score': 0.03609025478363037}
# {'uri': '/c/en/could/v', 'score': 0.03609025478363037}
#
# Node phrase: ['a', 'stew']
# {'uri': '/c/en/cook_stew', 'score': 0.06933695077896118}
# {'uri': '/c/en/cooking_stew', 'score': 0.06829679012298584}
# {'uri': '/c/en/make_stew', 'score': 0.06739199161529541}
# {'uri': '/c/en/in_stew', 'score': 0.06459510326385498}
# {'uri': 'at:to_eat_stew', 'score': 0.05399513244628906}

# %%
draw(linkedG)
